# %% [markdown]
# <a href="https://colab.research.google.com/github/telsayed/IR-in-Arabic/blob/master/Summer2021/labs/day2/IR_in_Arabic_LabA_Indexing%26ExploringIndex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IR in Arabic** - Summer 2021 lab notebook 2

# %% [markdown]
# This is one of a series of Colab notebooks created for the **IR in Arabic** course. It demonstrates how we can index a collection, and how to access an index to visualize some index analysis.
#
# The **learning outcomes** of the this notebook are:
#
#
# *   PyTerrier setup.
# *   Preprocessing.
# *   Indexing a collection.
# *   Accessing and exploring the index.
#
# What is PyTerrier?
#
# **[PyTerrier](https://pyterrier.readthedocs.io/en/latest/)** is a Python framework, but uses the underlying [Terrier information retrieval](http://terrier.org/) toolkit for many indexing and retrieval operations. While PyTerrier was new in 2020, Terrier is written in Java and has a long history dating back to 2001. PyTerrier makes it easy to perform IR experiments in Python, but using the mature Terrier platform for the expensive indexing and retrieval operations.

# %% [markdown]
# ### **Setup**
# We will first install Pyterrier as follows:

# %%
#install the Pyterrier framework
# !pip install python-terrier
# Out:
# Requirement already satisfied: python-terrier in /usr/local/lib/python3.7/dist-packages (0.6.0)
# Requirement already satisfied: chest in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.11.3)
# Requirement already satisfied: ir-measures>=0.1.4 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.19.5)
# Requirement already satisfied: pyjnius~=1.3.0 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.0.1)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.1.5)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.7/dist-packages (from python-terrier) (8.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from python-terrier) (4.41.1)
# Requirement already satisfied: matchpy in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.5.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.23.0)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.7/dist-packages (from python-terrier) (2.1.0)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.10.2)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.0)
# Requirement already satisfied: ir-datasets>=0.3.2 in /usr/local/lib/python3.7/dist-packages (from python-terrier) (0.3.3)
# Requirement already satisfied: nptyping in /usr/local/lib/python3.7/dist-packages (from python-terrier) (1.4.2)
# Requirement already satisfied: wget in /usr/local/lib/python3.7/dist-packages (from python-terrier) (3.2)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->python-terrier) (2.0.0)
# Requirement already satisfied: pytrec-eval-terrier==0.5.1 in /usr/local/lib/python3.7/dist-packages (from ir-measures>=0.1.4->python-terrier) (0.5.1)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (1.15.0)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from pyjnius~=1.3.0->python-terrier) (0.29.23)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->python-terrier) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.0->python-terrier) (2018.9)
# Requirement already satisfied: multiset<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->python-terrier) (1.24.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from deprecation->python-terrier) (20.9)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->python-terrier) (0.5.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->python-terrier) (0.22.2.post1)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.7/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.6.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.7/dist-packages (from ir-datasets>=0.3.2->python-terrier) (5.4.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.7/dist-packages (from ir-datasets>=0.3.2->python-terrier) (2.5.4)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.7/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.6.3)
# Requirement already satisfied: lz4>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from ir-datasets>=0.3.2->python-terrier) (3.1.3)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.7/dist-packages (from ir-datasets>=0.3.2->python-terrier) (3.1.4)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: typish>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from nptyping->python-terrier) (1.9.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->deprecation->python-terrier) (2.4.7)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier) (1.0.0)

# %% [markdown]
# The next step is to initialise PyTerrier. This is performed using PyTerrier's init() method. The init() method is needed as PyTerrier must download Terrier's jar file and start the Java virtual machine. We prevent init() from being called more than once by checking started().

# %%
import pyterrier as pt
if not pt.started():
  pt.init()

# %% [markdown]
# Another library that we need for this lab is Arabic-Stopwords

# %%
#install the Arabic stop words library
# !pip install Arabic-Stopwords
# Out:
# Requirement already satisfied: Arabic-Stopwords in /usr/local/lib/python3.7/dist-packages (0.3)
# Requirement already satisfied: pyarabic>=0.6.2 in /usr/local/lib/python3.7/dist-packages (from Arabic-Stopwords) (0.6.10)

# %% [markdown]
# We will import all the python libraries needed for this lab

# %%
#we need to import the following libraries.
import pandas as pd
#to display the full text on the notebook without truncation
pd.set_option('display.max_colwidth', 150)
import re
from snowballstemmer import stemmer
from tqdm import tqdm
import arabicstopwords.arabicstopwords as stp

# %% [markdown]
# ### **Data preparation**
# We will first create five textual documents.

# %%
docs_df = pd.DataFrame([ ["d0", "هذا هو اليوم الأول من دورة استرجاع المعلومات"],
                        ["d1", "الدورة باللغة العربية للطلاب العرب"], 
                        ["d2", "اليوم هو 30 مايو 2021"], 
                        ["d3", "نأمل أن تفيد هذه الدورة الطلاب العرب"],
                        ["d4", "هل أنتم سعداء بهذه التجربة؟"] ],
                        columns=["docno", "text"])

docs_df
# Out:
#   docno                                          text
# 0    d0  هذا هو اليوم الأول من دورة استرجاع المعلومات
# 1    d1            الدورة باللغة العربية للطلاب العرب
# 2    d2                         اليوم هو 30 مايو 2021
# 3    d3          نأمل أن تفيد هذه الدورة الطلاب العرب
# 4    d4                   هل أنتم سعداء بهذه التجربة؟

# %% [markdown]
# Before indexing our data we need to do the following processing steps:
#
#
# 1.   **Remove stopwords.**
# 2.   **Normalization.**
# 3.   **Stemming.**

# %% [markdown]
# Let's remove the stopwords.

# %%
#removing Stop Words function
def RemoveStopWords(sentence):
    terms=[]
    stopWords= set(stp.stopwords_list())
    for term in sentence.split() : 
        if term not in stopWords :
           terms.append(term)
    return " ".join(terms)
docs_df["text"]=docs_df["text"].apply(RemoveStopWords)
docs_df
# Out:
#   docno                                text
# 0    d0  اليوم الأول دورة استرجاع المعلومات
# 1    d1  الدورة باللغة العربية للطلاب العرب
# 2    d2                  اليوم 30 مايو 2021
# 3    d3       نأمل تفيد الدورة الطلاب العرب
# 4    d4                      سعداء التجربة؟

# %% [markdown]
# After removing the stopwords the next step is to normalize our documents.

# %%
#a function to normalize the tweets
def normalize(text):
    text = re.sub("[إأٱآا]", "ا", text)
    text = re.sub("ى", "ي", text)
    text = re.sub("ؤ", "ء", text)
    text = re.sub("ئ", "ء", text)
    text = re.sub("ة", "ه", text)
    return(text)

docs_df["text"]=docs_df["text"].apply(normalize)
print("***************************************************************************documents after normalizing*********************************************************************")
print(docs_df[['docno','text']])
# Out:
# ***************************************************************************documents after normalizing*********************************************************************
#   docno                                text
# 0    d0  اليوم الاول دوره استرجاع المعلومات
# 1    d1  الدوره باللغه العربيه للطلاب العرب
# 2    d2                  اليوم 30 مايو 2021
# 3    d3       نامل تفيد الدوره الطلاب العرب
# 4    d4                      سعداء التجربه؟

# %% [markdown]
# The last processing step is to stem the terms in each document.

# %%
ar_stemmer = stemmer("arabic")
docs_text=docs_df['text'].tolist()
output = []
for text in tqdm(docs_text):
    output.append(" ".join([ar_stemmer.stemWord(i) for i in text.split()]))
docs_df['text']=output
docs_df
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 225.82it/s]
#   docno                       text
# 0    d0  يوم اول دور استرجاع معلوم
# 1    d1       دور لغه عرب طلاب عرب
# 2    d2           يوم 30 مايو 2021
# 3    d3     نامل تفيد دور طلاب عرب
# 4    d4               سعداء تجربه؟

# %% [markdown]
# Next, we will index the dataframe's documents. The index, with all its data structures, is saved into a directory called **myFirstIndex**.

# %%
indexer = pt.DFIndexer("./myFirstIndex", overwrite=True)
#as the default id an English tokenizer we will update it by setting it to a non-English tokenizer "UTFTokenizer"
indexer.setProperty("tokeniser", "UTFTokeniser")
index_ref = indexer.index(docs_df["text"], docs_df["docno"])
index_ref.toString()
# Out:
# './myFirstIndex/data.properties'

# %% [markdown]
# ### **Explore the index**
# An index has several data structures:
#
# *    **the CollectionStatistics**- the salient global statistics of the index.
# *    **the Lexicon** - the vocabulary of the index, including statistics of the terms, and a pointer into the inverted index.
#
# * **the inverted index (a PostingIndex**) - contains the posting list for each term, detailing the frequency in which aterm appears in that document .
# * **the DocumentIndex** - contains the length of the document (and other field lengths).
# * **the MetaIndex** - contains document metadata, such as the docno, and optionally the raw text and the URL ofeach document.
# * **the direct index (also a PostingIndex)** - contains a posting list for each document, detailing which terms occuringthat document and which frequency. The presence of the direct index depends on the IndexingType that has beenapplied - single-pass and some memory indices do not provide a direct index.

# %%
# !rm myFirstIndex/*
# !ls -lh myFirstIndex/
# Out:
# total 40K
# -rw-r--r-- 1 root root   10 May 25 10:52 data.direct.bf
# -rw-r--r-- 1 root root   85 May 25 10:52 data.document.fsarrayfile
# -rw-r--r-- 1 root root   11 May 25 10:52 data.inverted.bf
# -rw-r--r-- 1 root root 1.3K May 25 10:52 data.lexicon.fsomapfile
# -rw-r--r-- 1 root root  441 May 25 10:52 data.lexicon.fsomaphash
# -rw-r--r-- 1 root root   60 May 25 10:52 data.lexicon.fsomapid
# -rw-r--r-- 1 root root   40 May 25 10:52 data.meta.idx
# -rw-r--r-- 1 root root   80 May 25 10:52 data.meta.zdata
# -rw-r--r-- 1 root root 4.1K May 25 10:52 data.properties

# %% [markdown]
# Let's check the statistics about the index we created.

# %%
#we will first load the index
index = pt.IndexFactory.of(index_ref)
#we will call getCollectionStatistics() to check the stats
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 5
# Number of terms: 15
# Number of postings: 20
# Number of fields: 0
# Number of tokens: 21
# Field names: []
# Positions:   false

# %% [markdown]
# We can check the lexicon which is the **vocabulary** of the collection.

# %%
for kv in index.getLexicon():
  print("%s -> %s " % (kv.getKey(), kv.getValue().toString()))
# Out:
# 2021 -> term10 Nt=1 TF=1 maxTF=1 @{0 0 0}
# 30 -> term8 Nt=1 TF=1 maxTF=1 @{0 0 4}
# استرجاع -> term0 Nt=1 TF=1 maxTF=1 @{0 1 0}
# اول -> term1 Nt=1 TF=1 maxTF=1 @{0 1 2}
# تجربه -> term14 Nt=1 TF=1 maxTF=1 @{0 1 4}
# تفيد -> term12 Nt=1 TF=1 maxTF=1 @{0 2 2}
# دور -> term2 Nt=3 TF=3 maxTF=1 @{0 3 0}
# سعداء -> term13 Nt=1 TF=1 maxTF=1 @{0 4 0}
# طلاب -> term6 Nt=2 TF=2 maxTF=1 @{0 4 6}
# عرب -> term7 Nt=2 TF=3 maxTF=2 @{0 5 6}
# لغه -> term5 Nt=1 TF=1 maxTF=1 @{0 6 7}
# مايو -> term9 Nt=1 TF=1 maxTF=1 @{0 7 3}
# معلوم -> term4 Nt=1 TF=1 maxTF=1 @{0 7 7}
# نامل -> term11 Nt=1 TF=1 maxTF=1 @{0 8 1}
# يوم -> term3 Nt=2 TF=2 maxTF=1 @{0 8 7}

# %% [markdown]
# The inverted index tells us in which documents each term occurs in.
# The LexiconEntry is the pointer that tell us where to find the postings for that term in the inverted index.
#
# Let's look in which documents the word "العرب" occurs and its frequency in each document.

# %%
term="العرب"
term=normalize(term)
term=ar_stemmer.stemWord(term)
print("the term after normalization and stemming:", term)
pointer = index.getLexicon()[term]
for posting in index.getInvertedIndex().getPostings(pointer):
    print(posting.toString() + " doclen=%d" % posting.getDocumentLength())
# Out:
# the term after normalization and stemming: عرب
# ID(1) TF(2) doclen=5
# ID(3) TF(1) doclen=5

# %% [markdown]
# How many documents does term "العرب" occur in?

# %%
index.getLexicon()[term].getDocumentFrequency()
# Out:
# 2

# %% [markdown]
# What terms occur in the 4th document?

# %%
di = index.getDirectIndex()
doi = index.getDocumentIndex()
lex = index.getLexicon()
docid = 3 #docids are 0-based #note: postings will be null if the document is empty
for posting in di.getPostings(doi.getDocumentEntry(docid)):
    termid = posting.getId()
    lee = lex.getLexiconEntry(termid)
    print("%s with frequency %d" % (lee.getKey(),posting.getFrequency()))
# Out:
# دور with frequency 1
# طلاب with frequency 1
# عرب with frequency 1
# نامل with frequency 1
# تفيد with frequency 1

# %% [markdown]
# ### **Indexing a bigger collection**
# **[EveTAR](https://link.springer.com/article/10.1007/s10791-017-9325-7)**, the first freely-available tweet test collection for multiple IR tasks. EveTAR includes a crawl of 355M Arabic tweets and covers 50 significant events for which about 62K tweets were judged with substantial average inter-annotator agreement (Kappa value of 0.71).
#
# First, we need to read the data from our Github repository. Note that we will use only a subset of 50K tweets in this lab.

# %%
dataset_links=["https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-01.txt",
               "https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-02.txt",
               "https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-03.txt",
               "https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-04.txt",
               "https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-05.txt",
               "https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-06.txt",
               "https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-07.txt",
               "https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-08.txt",
               "https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-09.txt",
               "https://raw.githubusercontent.com/telsayed/IR-in-Arabic/master/Summer2021/data/EveTAR/tweets/evetar-q-10.txt"]

full_data=pd.DataFrame()
for i in tqdm(range(len(dataset_links))):
    tweets=pd.read_csv(dataset_links[i], sep='\t')
    full_data=pd.concat([full_data,tweets],ignore_index=True)
full_data.reset_index(inplace=True,drop=True)
#the docno will be our tweetID
full_data["docno"]=full_data["tweetID"].astype(str)
full_data
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 10.13it/s]
#                   tweetID  ...               docno
# 0      549679192804061184  ...  549679192804061184
# 1      549699343666532352  ...  549699343666532352
# 2      549711593487888387  ...  549711593487888387
# 3      549719610459967488  ...  549719610459967488
# 4      549720880717508608  ...  549720880717508608
# ...                   ...  ...                 ...
# 49995  561985373048299520  ...  561985373048299520
# 49996  561987332878766081  ...  561987332878766081
# 49997  561988825186971650  ...  561988825186971650
# 49998  561991173360091136  ...  561991173360091136
# 49999  561991342402715650  ...  561991342402715650
#
# [50000 rows x 3 columns]

# %% [markdown]
# We will perform the same processing steps mentioned above but because we will index a collection of the tweets we need to clean the tweets before the other processsing steps them (remove the urls, emojies....)

# %%
#a function to clean the tweets
def clean(text):
   text = re.sub(r"http\S+", " ", text) # remove urls
   text = re.sub(r"RT ", " ", text) # remove rt
   text = re.sub(r"@[\w]*", " ", text) # remove handles
   text = re.sub(r"[\.\,\#_\|\:\?\?\/\=]", " ", text) # remove special characters
   text = re.sub(r'\t', ' ', text) # remove tabs
   text = re.sub(r'\n', ' ', text) # remove line jump
   text = re.sub(r"\s+", " ", text) # remove extra white space
   accents = re.compile(r'[\u064b-\u0652\u0640]') # harakaat and tatweel (kashida) to remove
     
   arabic_punc= re.compile(r'[\u0621-\u063A\u0641-\u064A\d+]+') # Keep only Arabic letters/do not remove number
   text=' '.join(arabic_punc.findall(accents.sub('',text)))
   text = text.strip()
   return text
#we will clean each tweet in the collection
print("***************************************************************************Tweets before cleaning*********************************************************************")
print(full_data[['docno','tweetText']])
full_data["tweetText"]=full_data["tweetText"].apply(clean)
print("***************************************************************************Tweets after cleaning*********************************************************************")
print(full_data[['docno','tweetText']])
# Out:
# ***************************************************************************Tweets before cleaning*********************************************************************
#                     docno                                                                                                                                   tweetText
# 0      549679192804061184  الاعدام لعامل مطعم قتل زميله طعناً في "البيادر" أيدت محكمة التمييز الحكم الصادر عن محكمة الجنايات الكبرى والقاضي... http://t.co/H0txdjv3Kn
# 1      549699343666532352    #الأخبار ▪ تأجيل محاكمة 7 إرهابيين بسبب غياب الدفاع: أجلت محكمة الجنايات بالعاصمة إلى تاريخ لاحق محاكمة سبعة إ... http://t.co/GM4jmpAWbR
# 2      549711593487888387                                          @helale9999 عشآن أعطيتك وحده صميم صرت ترمي أعذار ...حقق العالميةة و أرجع كلمني يَ الأياب الانتحاري
# 3      549719610459967488                          #النهدي ثمانية قتلى في تفجير انتحاري بسيارة مفخخة أمام معملين للغاز في ريف حمص - شبكة الصين http://t.co/r5zFEuzAPu
# 4      549720880717508608                                          البحرين: ضبط مطلوبين متورطين في التفجير بالعكر الشرقي بقية الموضوع اضغط هنا http://t.co/t4A5bNrqyh
# ...                   ...                                                                                                                                         ...
# 49995  561985373048299520                         مواسيا الشعب السعودي..حاكم دبي يبدأ جلسة مجلس الوزراء بقراءة الفاتحة على الملك عبدالله #الخبر #السعودية #saudi #ksa
# 49996  561987332878766081                                                                                                         @al_shalal @F_D_A82 تم تفجير صماخنا
# 49997  561988825186971650                                                          @aubyazid123 جزاك الله ألف خير ❌ جزاك الله خير ✔️ - كلمة ألف فيها تحجير لخير الله.
# 49998  561991173360091136                                                           كيف نفّذت «النصرة» عمليّة تفجير الحافلة اللبنانية في دمشق؟ http://t.co/TEmP1Dso1v
# 49999  561991342402715650                                                               @zvasoo جزاك الله ألف خير ❌ جزاك الله خير ✔️ - كلمة ألف فيها تحجير لخير الله.
#
# [50000 rows x 2 columns]
# ***************************************************************************Tweets after cleaning*********************************************************************
#                     docno                                                                                                      tweetText
# 0      549679192804061184  الاعدام لعامل مطعم قتل زميله طعنا في البيادر أيدت محكمة التمييز الحكم الصادر عن محكمة الجنايات الكبرى والقاضي
# 1      549699343666532352     الأخبار تأجيل محاكمة 7 إرهابيين بسبب غياب الدفاع أجلت محكمة الجنايات بالعاصمة إلى تاريخ لاحق محاكمة سبعة إ
# 2      549711593487888387                             عشآن أعطيتك وحده صميم صرت ترمي أعذار حقق العالميةة و أرجع كلمني ي الأياب الانتحاري
# 3      549719610459967488                       النهدي ثمانية قتلى في تفجير انتحاري بسيارة مفخخة أمام معملين للغاز في ريف حمص شبكة الصين
# 4      549720880717508608                                     البحرين ضبط مطلوبين متورطين في التفجير بالعكر الشرقي بقية الموضوع اضغط هنا
# ...                   ...                                                                                                            ...
# 49995  561985373048299520           مواسيا الشعب السعودي حاكم دبي يبدأ جلسة مجلس الوزراء بقراءة الفاتحة على الملك عبدالله الخبر السعودية
# 49996  561987332878766081                                                                                                تم تفجير صماخنا
# 49997  561988825186971650                                                  جزاك الله ألف خير جزاك الله خير كلمة ألف فيها تحجير لخير الله
# 49998  561991173360091136                                                          كيف نفذت النصرة عملية تفجير الحافلة اللبنانية في دمشق
# 49999  561991342402715650                                                  جزاك الله ألف خير جزاك الله خير كلمة ألف فيها تحجير لخير الله
#
# [50000 rows x 2 columns]

# %% [markdown]
# We will remove the stop words.

# %%
full_data["tweetText"]=full_data["tweetText"].apply(RemoveStopWords)
print("***************************************************************************Tweets after removing stopWords*********************************************************************")
print(full_data[['docno','tweetText']])
# Out:
# ***************************************************************************Tweets after removing stopWords*********************************************************************
#                     docno                                                                                                tweetText
# 0      549679192804061184  الاعدام لعامل مطعم قتل زميله طعنا البيادر أيدت محكمة التمييز الحكم الصادر محكمة الجنايات الكبرى والقاضي
# 1      549699343666532352   الأخبار تأجيل محاكمة 7 إرهابيين بسبب غياب الدفاع أجلت محكمة الجنايات بالعاصمة تاريخ لاحق محاكمة سبعة إ
# 2      549711593487888387                           عشآن أعطيتك وحده صميم صرت ترمي أعذار حقق العالميةة أرجع كلمني الأياب الانتحاري
# 3      549719610459967488                            النهدي ثمانية قتلى تفجير انتحاري بسيارة مفخخة معملين للغاز ريف حمص شبكة الصين
# 4      549720880717508608                                      البحرين ضبط مطلوبين متورطين التفجير بالعكر الشرقي بقية الموضوع اضغط
# ...                   ...                                                                                                      ...
# 49995  561985373048299520         مواسيا الشعب السعودي حاكم دبي يبدأ جلسة مجلس الوزراء بقراءة الفاتحة الملك عبدالله الخبر السعودية
# 49996  561987332878766081                                                                                          تم تفجير صماخنا
# 49997  561988825186971650                                                 جزاك الله ألف خير جزاك الله خير كلمة ألف تحجير لخير الله
# 49998  561991173360091136                                                           نفذت النصرة عملية تفجير الحافلة اللبنانية دمشق
# 49999  561991342402715650                                                 جزاك الله ألف خير جزاك الله خير كلمة ألف تحجير لخير الله
#
# [50000 rows x 2 columns]

# %% [markdown]
# We also need to normalize the tweets

# %%
#we will normalize using our normalize function. 
full_data["tweetText"]=full_data["tweetText"].apply(normalize)
print("***************************************************************************Tweets after normalizing*********************************************************************")
print(full_data[['docno','tweetText']])
# Out:
# ***************************************************************************Tweets after normalizing*********************************************************************
#                     docno                                                                                                tweetText
# 0      549679192804061184  الاعدام لعامل مطعم قتل زميله طعنا البيادر ايدت محكمه التمييز الحكم الصادر محكمه الجنايات الكبري والقاضي
# 1      549699343666532352   الاخبار تاجيل محاكمه 7 ارهابيين بسبب غياب الدفاع اجلت محكمه الجنايات بالعاصمه تاريخ لاحق محاكمه سبعه ا
# 2      549711593487888387                           عشان اعطيتك وحده صميم صرت ترمي اعذار حقق العالميهه ارجع كلمني الاياب الانتحاري
# 3      549719610459967488                            النهدي ثمانيه قتلي تفجير انتحاري بسياره مفخخه معملين للغاز ريف حمص شبكه الصين
# 4      549720880717508608                                      البحرين ضبط مطلوبين متورطين التفجير بالعكر الشرقي بقيه الموضوع اضغط
# ...                   ...                                                                                                      ...
# 49995  561985373048299520         مواسيا الشعب السعودي حاكم دبي يبدا جلسه مجلس الوزراء بقراءه الفاتحه الملك عبدالله الخبر السعوديه
# 49996  561987332878766081                                                                                          تم تفجير صماخنا
# 49997  561988825186971650                                                 جزاك الله الف خير جزاك الله خير كلمه الف تحجير لخير الله
# 49998  561991173360091136                                                           نفذت النصره عمليه تفجير الحافله اللبنانيه دمشق
# 49999  561991342402715650                                                 جزاك الله الف خير جزاك الله خير كلمه الف تحجير لخير الله
#
# [50000 rows x 2 columns]

# %% [markdown]
# Stemming the collection (this will take time up 2 minutes)

# %%
tweets_text=full_data['tweetText'].tolist()
output = []
for tweet in tqdm(tweets_text):
    output.append(" ".join([ar_stemmer.stemWord(i) for i in tweet.split()]))
full_data['tweetText']=output
# Out:
# 100%|██████████| 50000/50000 [01:39<00:00, 501.83it/s]

# %%
#the tweets after stemming
print(full_data[['docno','tweetText']])
# Out:
#                     docno                                                                         tweetText
# 0      549679192804061184  اعدام لعامل مطعم قتل زميل طعنا بيادر ايد محكم تمييز حكم صادر محكم جنا كبر والقاض
# 1      549699343666532352    اخبار تاجيل محا 7 ارهابي سبب غياب دفاع اجل محكم جنا عاصمه تاريخ لاحق محا سبع ا
# 2      549711593487888387                 عشان اعطي وحد صميم صرت ترم اعذار حقق عالميهه ارجع كلم اياب انتحار
# 3      549719610459967488                       نهد ثما قتل تفجير انتحار سيار مفخخ معمل غاز ريف حمص شبك صين
# 4      549720880717508608                                  بحر ضبط مطلوب متورط تفجير عكر شرق بقي موضوع اضغط
# ...                   ...                                                                               ...
# 49995  561985373048299520        مواسي شعب سعود حاكم دب يبد جلس مجلس وزراء قراء فاتحه ملك عبدالل خبر سعوديه
# 49996  561987332878766081                                                                     تم تفجير صماخ
# 49997  561988825186971650                             جزا الله الف خير جزا الله خير كلم الف تحجير لخير الله
# 49998  561991173360091136                                             نفذ نصره عمل تفجير حافله لبنانيه دمشق
# 49999  561991342402715650                             جزا الله الف خير جزا الله خير كلم الف تحجير لخير الله
#
# [50000 rows x 2 columns]

# %% [markdown]
# ### **Indexing EveTAR**

# %%
indexer = pt.DFIndexer("./evetarIndex", overwrite=True)
#as the default id an English tokenizer we will update it by setting it to a non-English tokenizer "UTFTokenizer"
indexer.setProperty("tokeniser", "UTFTokeniser")
index_ref = indexer.index(full_data["tweetText"], full_data["docno"])
index_ref.toString()
# Out:
# './evetarIndex/data.properties'

# %% [markdown]
# ### **Explore the index**

# %%
#we will first load the index
index = pt.IndexFactory.of(index_ref)
#we will call getCollectionStatistics() to check the stats
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 50000
# Number of terms: 25045
# Number of postings: 499710
# Number of fields: 0
# Number of tokens: 537706
# Field names: []
# Positions:   false

# %% [markdown]
# **A note to the tester:** Please check the vocab below is و a stop word, check words such as و اللاعب  and و الليل ....
#  also words such as هالاسبوع are not ها should be removed during stemming

# %%
#check the vocab
for kv in index.getLexicon():
  print("%s -> %s " % (kv.getKey(), kv.getValue().toString()))
# Out:
# Streaming output truncated to the last 5000 lines.
# نطلق -> term13464 Nt=3 TF=3 maxTF=1 @{0 593081 4}
# نطم -> term19640 Nt=2 TF=2 maxTF=1 @{0 593092 0}
# نطو -> term16197 Nt=1 TF=1 maxTF=1 @{0 593099 4}
# نطيط -> term24695 Nt=3 TF=3 maxTF=1 @{0 593103 2}
# نظ -> term18812 Nt=1 TF=1 maxTF=1 @{0 593111 6}
# نظاف -> term11993 Nt=5 TF=5 maxTF=1 @{0 593115 4}
# نظافه -> term22054 Nt=1 TF=1 maxTF=1 @{0 593128 0}
# نظاكم -> term22460 Nt=1 TF=1 maxTF=1 @{0 593132 0}
# نظال -> term21681 Nt=1 TF=1 maxTF=1 @{0 593136 0}
# نظام -> term1494 Nt=127 TF=132 maxTF=2 @{0 593140 0}
# نظر -> term284 Nt=79 TF=81 maxTF=2 @{0 593379 5}
# نظرا -> term16981 Nt=3 TF=3 maxTF=1 @{0 593533 1}
# نظرت -> term19771 Nt=1 TF=1 maxTF=1 @{0 593541 5}
# نظف -> term21784 Nt=1 TF=1 maxTF=1 @{0 593545 5}
# نظل -> term21909 Nt=1 TF=1 maxTF=1 @{0 593549 5}
# نظم -> term1053 Nt=15 TF=15 maxTF=1 @{0 593553 5}
# نظير -> term12355 Nt=51 TF=51 maxTF=1 @{0 593589 1}
# نظيف -> term13930 Nt=21 TF=21 maxTF=1 @{0 593672 3}
# نع -> term19481 Nt=1 TF=1 maxTF=1 @{0 593717 1}
# نعا -> term9050 Nt=1 TF=1 maxTF=1 @{0 593720 7}
# نعاج -> term12638 Nt=3 TF=3 maxTF=1 @{0 593724 3}
# نعارض -> term1807 Nt=2 TF=2 maxTF=1 @{0 593734 3}
# نعاس -> term336 Nt=3 TF=3 maxTF=1 @{0 593738 1}
# نعاطف -> term2586 Nt=1 TF=1 maxTF=1 @{0 593746 1}
# نعاقب -> term3072 Nt=1 TF=1 maxTF=1 @{0 593748 7}
# نعام -> term15140 Nt=1 TF=1 maxTF=1 @{0 593751 5}
# نعامل -> term22701 Nt=1 TF=1 maxTF=1 @{0 593755 3}
# نعان -> term1821 Nt=1 TF=1 maxTF=1 @{0 593759 3}
# نعت -> term7901 Nt=8 TF=8 maxTF=1 @{0 593761 7}
# نعتبر -> term7154 Nt=4 TF=4 maxTF=1 @{0 593782 7}
# نعتد -> term7364 Nt=2 TF=2 maxTF=1 @{0 593795 5}
# نعتذر -> term20627 Nt=1 TF=1 maxTF=1 @{0 593802 7}
# نعترف -> term24387 Nt=1 TF=1 maxTF=1 @{0 593806 7}
# نعتزل -> term13501 Nt=1 TF=1 maxTF=1 @{0 593810 7}
# نعتزم -> term19982 Nt=1 TF=1 maxTF=1 @{0 593814 5}
# نعتقد -> term10635 Nt=2 TF=2 maxTF=1 @{0 593818 5}
# نعتمد -> term5906 Nt=2 TF=2 maxTF=1 @{0 593826 1}
# نعج -> term10600 Nt=2 TF=2 maxTF=1 @{0 593832 7}
# نعجز -> term16053 Nt=2 TF=2 maxTF=1 @{0 593840 1}
# نعجه -> term19310 Nt=1 TF=1 maxTF=1 @{0 593846 7}
# نعد -> term10161 Nt=4 TF=4 maxTF=1 @{0 593850 5}
# نعذر -> term5843 Nt=2 TF=2 maxTF=1 @{0 593864 5}
# نعرف -> term2753 Nt=15 TF=16 maxTF=2 @{0 593871 3}
# نعش -> term19413 Nt=1 TF=1 maxTF=1 @{0 593914 6}
# نعشق -> term8912 Nt=2 TF=2 maxTF=1 @{0 593918 4}
# نعط -> term19811 Nt=1 TF=1 maxTF=1 @{0 593925 0}
# نعف -> term11537 Nt=1 TF=1 maxTF=1 @{0 593929 0}
# نعل -> term9707 Nt=2 TF=2 maxTF=1 @{0 593932 4}
# نعلم -> term5330 Nt=12 TF=12 maxTF=1 @{0 593939 6}
# نعليك -> term24509 Nt=1 TF=1 maxTF=1 @{0 593966 2}
# نعم -> term7760 Nt=5 TF=5 maxTF=1 @{0 593970 2}
# نعمان -> term10980 Nt=3 TF=3 maxTF=1 @{0 593986 2}
# نعمر -> term3016 Nt=7 TF=7 maxTF=1 @{0 593996 4}
# نعمل -> term8085 Nt=12 TF=12 maxTF=1 @{0 594007 6}
# نعمه -> term17961 Nt=1 TF=1 maxTF=1 @{0 594042 0}
# نعود -> term2925 Nt=2 TF=2 maxTF=1 @{0 594045 6}
# نعوض -> term14573 Nt=4 TF=4 maxTF=1 @{0 594052 2}
# نعيد -> term5762 Nt=2 TF=2 maxTF=1 @{0 594065 6}
# نعيش -> term1259 Nt=4 TF=4 maxTF=1 @{0 594072 6}
# نعيم -> term22312 Nt=5 TF=5 maxTF=1 @{0 594085 2}
# نغ -> term8359 Nt=1 TF=1 maxTF=1 @{0 594098 2}
# نغادر -> term22665 Nt=1 TF=1 maxTF=1 @{0 594101 4}
# نغاز -> term8798 Nt=22 TF=23 maxTF=2 @{0 594105 4}
# نغافور -> term5754 Nt=14 TF=15 maxTF=2 @{0 594155 5}
# نغال -> term15467 Nt=3 TF=3 maxTF=1 @{0 594180 2}
# نغاو -> term7197 Nt=1 TF=1 maxTF=1 @{0 594189 4}
# نغرد -> term17761 Nt=1 TF=1 maxTF=1 @{0 594192 6}
# نغز -> term10572 Nt=2 TF=2 maxTF=1 @{0 594196 4}
# نغس -> term23443 Nt=1 TF=1 maxTF=1 @{0 594203 6}
# نغلق -> term7588 Nt=1 TF=1 maxTF=1 @{0 594207 6}
# نغن -> term13388 Nt=1 TF=1 maxTF=1 @{0 594211 0}
# نغير -> term18903 Nt=1 TF=1 maxTF=1 @{0 594214 6}
# نغيز -> term19514 Nt=1 TF=1 maxTF=1 @{0 594218 4}
# نغيظ -> term17694 Nt=1 TF=1 maxTF=1 @{0 594222 2}
# نف -> term7228 Nt=11 TF=11 maxTF=1 @{0 594226 0}
# نفا -> term15175 Nt=2 TF=2 maxTF=1 @{0 594255 6}
# نفاذ -> term144 Nt=19 TF=19 maxTF=1 @{0 594262 4}
# نفاصيل -> term1768 Nt=1 TF=1 maxTF=1 @{0 594278 6}
# نفاق -> term3878 Nt=9 TF=11 maxTF=2 @{0 594281 2}
# نفتح -> term16196 Nt=2 TF=2 maxTF=1 @{0 594306 6}
# نفتقد -> term4959 Nt=3 TF=3 maxTF=1 @{0 594313 6}
# نفجر -> term8072 Nt=3 TF=3 maxTF=1 @{0 594323 4}
# نفجرل -> term24732 Nt=1 TF=1 maxTF=1 @{0 594334 0}
# نفخ -> term13769 Nt=1 TF=1 maxTF=1 @{0 594338 0}
# نفخر -> term20358 Nt=1 TF=1 maxTF=1 @{0 594341 6}
# نفد -> term11250 Nt=3 TF=3 maxTF=1 @{0 594345 6}
# نفذ -> term319 Nt=421 TF=423 maxTF=2 @{0 594355 4}
# نفذ2 -> term24790 Nt=1 TF=1 maxTF=1 @{0 594836 2}
# نفر -> term17017 Nt=1 TF=1 maxTF=1 @{0 594840 2}
# نفرح -> term9561 Nt=5 TF=5 maxTF=1 @{0 594844 0}
# نفرستاد -> term16067 Nt=1 TF=1 maxTF=1 @{0 594860 2}
# نفرض -> term17626 Nt=1 TF=1 maxTF=1 @{0 594864 0}
# نفرط -> term21758 Nt=1 TF=1 maxTF=1 @{0 594867 6}
# نفرطش -> term24353 Nt=1 TF=1 maxTF=1 @{0 594871 6}
# نفرق -> term15990 Nt=1 TF=1 maxTF=1 @{0 594875 6}
# نفس -> term1986 Nt=75 TF=76 maxTF=2 @{0 594879 4}
# نفسج -> term12809 Nt=2 TF=2 maxTF=1 @{0 595016 7}
# نفسد -> term17431 Nt=1 TF=1 maxTF=1 @{0 595024 3}
# نفسيت -> term20203 Nt=1 TF=1 maxTF=1 @{0 595028 1}
# نفض -> term1955 Nt=8 TF=8 maxTF=1 @{0 595032 1}
# نفط -> term4038 Nt=331 TF=370 maxTF=4 @{0 595052 3}
# نفطيه -> term8705 Nt=6 TF=6 maxTF=1 @{0 595362 4}
# نفظ -> term6435 Nt=1 TF=1 maxTF=1 @{0 595376 4}
# نفع -> term4582 Nt=7 TF=7 maxTF=1 @{0 595379 6}
# نفعل -> term19547 Nt=2 TF=2 maxTF=1 @{0 595400 0}
# نفق -> term1534 Nt=54 TF=54 maxTF=1 @{0 595407 0}
# نفقد -> term16113 Nt=1 TF=1 maxTF=1 @{0 595490 4}
# نفل -> term20960 Nt=1 TF=1 maxTF=1 @{0 595494 2}
# نفلح -> term16361 Nt=1 TF=1 maxTF=1 @{0 595498 2}
# نفهم -> term6052 Nt=3 TF=3 maxTF=1 @{0 595502 0}
# نفوذ -> term16724 Nt=2 TF=2 maxTF=1 @{0 595512 4}
# نفوز -> term7526 Nt=25 TF=28 maxTF=4 @{0 595519 6}
# نفوس -> term10301 Nt=2 TF=2 maxTF=1 @{0 595571 7}
# نفوق -> term20579 Nt=1 TF=1 maxTF=1 @{0 595579 1}
# نفووز -> term19231 Nt=1 TF=1 maxTF=1 @{0 595583 1}
# نفيس -> term11076 Nt=1 TF=1 maxTF=1 @{0 595586 7}
# نفيسه -> term14758 Nt=1 TF=1 maxTF=1 @{0 595590 3}
# نق -> term19160 Nt=12 TF=12 maxTF=1 @{0 595594 1}
# نقااط -> term18425 Nt=1 TF=1 maxTF=1 @{0 595607 1}
# نقااوم -> term24388 Nt=1 TF=1 maxTF=1 @{0 595610 7}
# نقاب -> term1552 Nt=6 TF=6 maxTF=1 @{0 595614 7}
# نقابا -> term5669 Nt=7 TF=7 maxTF=1 @{0 595630 5}
# نقابل -> term18866 Nt=7 TF=9 maxTF=3 @{0 595649 3}
# نقاذ -> term22658 Nt=1 TF=1 maxTF=1 @{0 595666 7}
# نقار -> term21826 Nt=2 TF=2 maxTF=1 @{0 595670 7}
# نقاش -> term7109 Nt=36 TF=36 maxTF=1 @{0 595677 7}
# نقاش24 -> term17568 Nt=1 TF=1 maxTF=1 @{0 595748 3}
# نقاط -> term4532 Nt=38 TF=42 maxTF=4 @{0 595752 1}
# نقال -> term18509 Nt=2 TF=2 maxTF=1 @{0 595826 3}
# نقاله -> term15895 Nt=1 TF=1 maxTF=1 @{0 595830 3}
# نقاهه -> term17793 Nt=1 TF=1 maxTF=1 @{0 595834 1}
# نقبل -> term15744 Nt=8 TF=8 maxTF=1 @{0 595837 7}
# نقتل -> term13263 Nt=4 TF=4 maxTF=1 @{0 595850 5}
# نقد -> term1500 Nt=5 TF=5 maxTF=1 @{0 595860 1}
# نقدر -> term5782 Nt=10 TF=10 maxTF=1 @{0 595875 5}
# نقدرش -> term3073 Nt=1 TF=1 maxTF=1 @{0 595898 7}
# نقدم -> term811 Nt=8 TF=8 maxTF=1 @{0 595901 5}
# نقر -> term13698 Nt=4 TF=5 maxTF=2 @{0 595921 5}
# نقسيم -> term23902 Nt=2 TF=2 maxTF=1 @{0 595934 6}
# نقش -> term17664 Nt=1 TF=1 maxTF=1 @{0 595939 2}
# نقشبنديه -> term21994 Nt=1 TF=1 maxTF=1 @{0 595943 0}
# نقص -> term17419 Nt=11 TF=11 maxTF=1 @{0 595947 0}
# نقض -> term2782 Nt=472 TF=543 maxTF=3 @{0 595966 2}
# نقط -> term7423 Nt=94 TF=96 maxTF=2 @{0 596264 7}
# نقطت -> term18802 Nt=2 TF=2 maxTF=1 @{0 596421 1}
# نقطف -> term7567 Nt=1 TF=1 maxTF=1 @{0 596425 7}
# نقطه -> term16268 Nt=4 TF=4 maxTF=1 @{0 596429 1}
# نقطهحوار -> term9009 Nt=1 TF=1 maxTF=1 @{0 596441 7}
# نقعد -> term22370 Nt=1 TF=1 maxTF=1 @{0 596445 3}
# نقف -> term23209 Nt=6 TF=6 maxTF=1 @{0 596449 3}
# نقل -> term1240 Nt=219 TF=221 maxTF=2 @{0 596461 7}
# نقلب -> term8512 Nt=3 TF=3 maxTF=1 @{0 596788 3}
# نقلل -> term23488 Nt=1 TF=1 maxTF=1 @{0 596797 5}
# نقم -> term19028 Nt=2 TF=2 maxTF=1 @{0 596801 5}
# نقول -> term1365 Nt=30 TF=30 maxTF=1 @{0 596808 5}
# نقوم -> term5057 Nt=8 TF=8 maxTF=1 @{0 596883 1}
# نقيب -> term7852 Nt=9 TF=9 maxTF=1 @{0 596907 1}
# نقيه -> term9328 Nt=1 TF=1 maxTF=1 @{0 596930 7}
# نكا -> term4232 Nt=2 TF=2 maxTF=1 @{0 596934 3}
# نكاح -> term9936 Nt=6 TF=6 maxTF=1 @{0 596941 1}
# نكايه -> term24419 Nt=1 TF=1 maxTF=1 @{0 596960 1}
# نكب -> term2923 Nt=5 TF=5 maxTF=1 @{0 596964 1}
# نكبر -> term14249 Nt=1 TF=1 maxTF=1 @{0 596979 1}
# نكت -> term4964 Nt=4 TF=4 maxTF=1 @{0 596982 7}
# نكتب -> term13996 Nt=4 TF=4 maxTF=1 @{0 596995 7}
# نكتشف -> term3338 Nt=2 TF=2 maxTF=1 @{0 597009 3}
# نكتف -> term17356 Nt=2 TF=2 maxTF=1 @{0 597015 7}
# نكته -> term21614 Nt=1 TF=1 maxTF=1 @{0 597023 1}
# نكد -> term2079 Nt=3 TF=3 maxTF=1 @{0 597027 1}
# نكذب -> term2655 Nt=1 TF=1 maxTF=1 @{0 597037 1}
# نكراء -> term21049 Nt=2 TF=2 maxTF=1 @{0 597039 7}
# نكسا -> term22814 Nt=1 TF=1 maxTF=1 @{0 597046 7}
# نكسب -> term22227 Nt=1 TF=1 maxTF=1 @{0 597050 7}
# نكسون -> term22459 Nt=1 TF=1 maxTF=1 @{0 597054 7}
# نكشف -> term13781 Nt=4 TF=4 maxTF=1 @{0 597058 7}
# نكلم -> term14641 Nt=1 TF=1 maxTF=1 @{0 597071 3}
# نكليز -> term16477 Nt=1 TF=1 maxTF=1 @{0 597075 1}
# نكمل -> term14298 Nt=3 TF=3 maxTF=1 @{0 597078 7}
# نكن -> term10120 Nt=1 TF=1 maxTF=1 @{0 597089 3}
# نكه -> term21106 Nt=1 TF=1 maxTF=1 @{0 597092 7}
# نكوانتوم -> term18391 Nt=1 TF=1 maxTF=1 @{0 597096 7}
# نكون -> term5935 Nt=9 TF=12 maxTF=2 @{0 597100 5}
# نكير -> term4170 Nt=2 TF=2 maxTF=1 @{0 597126 2}
# نلاحق -> term13152 Nt=1 TF=1 maxTF=1 @{0 597132 4}
# نلاعب -> term19196 Nt=1 TF=1 maxTF=1 @{0 597136 2}
# نلاق -> term19252 Nt=1 TF=1 maxTF=1 @{0 597140 0}
# نلت -> term16139 Nt=1 TF=2 maxTF=2 @{0 597143 6}
# نلتق -> term18937 Nt=2 TF=2 maxTF=1 @{0 597147 5}
# نلح -> term13387 Nt=1 TF=1 maxTF=1 @{0 597154 7}
# نلحق -> term808 Nt=2 TF=2 maxTF=1 @{0 597158 5}
# نلع -> term17539 Nt=1 TF=1 maxTF=1 @{0 597164 5}
# نلعب -> term1584 Nt=31 TF=31 maxTF=1 @{0 597168 3}
# نلك -> term17128 Nt=1 TF=1 maxTF=1 @{0 597233 1}
# نلند -> term20766 Nt=3 TF=3 maxTF=1 @{0 597236 7}
# نلوم -> term13687 Nt=9 TF=17 maxTF=2 @{0 597247 1}
# نم -> term5361 Nt=1 TF=1 maxTF=1 @{0 597263 1}
# نمارس -> term11388 Nt=1 TF=1 maxTF=1 @{0 597266 1}
# نمانع -> term6948 Nt=12 TF=22 maxTF=2 @{0 597269 5}
# نمت -> term15343 Nt=3 TF=3 maxTF=1 @{0 597281 7}
# نمتل -> term18892 Nt=1 TF=1 maxTF=1 @{0 597292 3}
# نمثل -> term8277 Nt=1 TF=1 maxTF=1 @{0 597296 1}
# نمر -> term9303 Nt=16 TF=16 maxTF=1 @{0 597299 3}
# نمره -> term15998 Nt=1 TF=1 maxTF=1 @{0 597336 3}
# نمسا -> term9420 Nt=12 TF=12 maxTF=1 @{0 597340 1}
# نمساتسعه -> term14634 Nt=1 TF=1 maxTF=1 @{0 597372 5}
# نمنع -> term7096 Nt=1 TF=2 maxTF=2 @{0 597376 3}
# نمو -> term14355 Nt=7 TF=7 maxTF=1 @{0 597379 6}
# نموا -> term14354 Nt=1 TF=1 maxTF=1 @{0 597400 0}
# نموذج -> term6849 Nt=13 TF=13 maxTF=1 @{0 597403 6}
# نمور -> term18792 Nt=1 TF=1 maxTF=1 @{0 597438 0}
# نميل -> term6720 Nt=1 TF=1 maxTF=1 @{0 597441 6}
# ننام -> term24022 Nt=1 TF=1 maxTF=1 @{0 597445 0}
# ننتحر -> term15755 Nt=2 TF=2 maxTF=1 @{0 597449 0}
# ننتصر -> term20644 Nt=3 TF=5 maxTF=2 @{0 597455 4}
# ننتظ -> term20620 Nt=1 TF=1 maxTF=1 @{0 597465 6}
# ننتظر -> term5084 Nt=21 TF=21 maxTF=1 @{0 597469 6}
# ننتف -> term16210 Nt=1 TF=1 maxTF=1 @{0 597524 6}
# نندج -> term22889 Nt=1 TF=1 maxTF=1 @{0 597528 4}
# ننزل -> term8276 Nt=1 TF=1 maxTF=1 @{0 597532 4}
# ننس -> term3060 Nt=7 TF=7 maxTF=1 @{0 597535 6}
# ننشر -> term10637 Nt=28 TF=28 maxTF=1 @{0 597556 6}
# ننشرل -> term10292 Nt=4 TF=4 maxTF=1 @{0 597612 2}
# ننطلق -> term21602 Nt=1 TF=1 maxTF=1 @{0 597623 6}
# ننعلم -> term22720 Nt=1 TF=1 maxTF=1 @{0 597627 6}
# ننعم -> term7935 Nt=1 TF=1 maxTF=1 @{0 597631 6}
# ننف -> term23039 Nt=9 TF=10 maxTF=2 @{0 597635 0}
# ننفرد -> term20130 Nt=1 TF=1 maxTF=1 @{0 597646 7}
# ننفع -> term10801 Nt=2 TF=2 maxTF=1 @{0 597650 7}
# ننقب -> term5931 Nt=2 TF=2 maxTF=1 @{0 597655 3}
# ننقز -> term15951 Nt=1 TF=1 maxTF=1 @{0 597661 5}
# ننقل -> term20681 Nt=1 TF=1 maxTF=1 @{0 597665 3}
# ننكر -> term19327 Nt=1 TF=1 maxTF=1 @{0 597669 3}
# ننهزم -> term23029 Nt=1 TF=1 maxTF=1 @{0 597673 1}
# ننو -> term16022 Nt=4 TF=4 maxTF=1 @{0 597677 1}
# ننوس -> term4459 Nt=1 TF=1 maxTF=1 @{0 597686 1}
# ننوووس -> term8756 Nt=1 TF=1 maxTF=1 @{0 597689 1}
# ننيم -> term18367 Nt=1 TF=1 maxTF=1 @{0 597692 5}
# نه -> term6737 Nt=2 TF=3 maxTF=2 @{0 597696 3}
# نها -> term2692 Nt=81 TF=81 maxTF=1 @{0 597703 6}
# نهاء -> term5097 Nt=554 TF=577 maxTF=2 @{0 597836 2}
# نهاءي -> term9958 Nt=6 TF=6 maxTF=1 @{0 598285 1}
# نهاءيا -> term12120 Nt=60 TF=60 maxTF=1 @{0 598303 3}
# نهاءيه -> term1784 Nt=36 TF=36 maxTF=1 @{0 598381 5}
# نهاءيهبعد -> term21426 Nt=1 TF=1 maxTF=1 @{0 598446 1}
# نهااا -> term21420 Nt=1 TF=1 maxTF=1 @{0 598450 1}
# نهاب -> term18893 Nt=1 TF=1 maxTF=1 @{0 598454 1}
# نهاد -> term15652 Nt=15 TF=15 maxTF=1 @{0 598457 7}
# نهار -> term2997 Nt=62 TF=68 maxTF=2 @{0 598476 1}
# نهارد -> term3936 Nt=2 TF=2 maxTF=1 @{0 598596 7}
# نهارده -> term1987 Nt=26 TF=26 maxTF=1 @{0 598603 5}
# نهالعراق -> term23588 Nt=1 TF=1 maxTF=1 @{0 598668 1}
# نهاي -> term629 Nt=7 TF=7 maxTF=1 @{0 598672 1}
# نهايت -> term1671 Nt=2 TF=2 maxTF=1 @{0 598693 1}
# نهايه -> term4781 Nt=16 TF=16 maxTF=1 @{0 598699 3}
# نهب -> term13736 Nt=7 TF=7 maxTF=1 @{0 598736 5}
# نهتم -> term5717 Nt=1 TF=1 maxTF=1 @{0 598756 7}
# نهج -> term2891 Nt=4 TF=4 maxTF=1 @{0 598759 7}
# نهد -> term50 Nt=44 TF=46 maxTF=2 @{0 598773 3}
# نهر -> term8591 Nt=18 TF=18 maxTF=1 @{0 598846 7}
# نهرو -> term14281 Nt=5 TF=5 maxTF=1 @{0 598889 1}
# نهرين -> term20955 Nt=1 TF=1 maxTF=1 @{0 598902 5}
# نهزم -> term7486 Nt=3 TF=3 maxTF=1 @{0 598906 5}
# نهضم -> term21469 Nt=1 TF=1 maxTF=1 @{0 598916 7}
# نهضه -> term2807 Nt=16 TF=16 maxTF=1 @{0 598920 7}
# نهنء -> term21804 Nt=3 TF=3 maxTF=1 @{0 598966 3}
# نهوض -> term11711 Nt=1 TF=1 maxTF=1 @{0 598975 5}
# نو -> term675 Nt=3 TF=5 maxTF=2 @{0 598979 1}
# نوا -> term21955 Nt=1 TF=1 maxTF=1 @{0 598988 5}
# نواب -> term257 Nt=75 TF=78 maxTF=2 @{0 598992 5}
# نواج -> term5851 Nt=9 TF=9 maxTF=1 @{0 599101 0}
# نواح -> term10366 Nt=9 TF=9 maxTF=1 @{0 599122 4}
# نوادر -> term2030 Nt=3 TF=3 maxTF=1 @{0 599147 0}
# نواره -> term18374 Nt=1 TF=1 maxTF=1 @{0 599156 4}
# نواصل -> term6844 Nt=10 TF=10 maxTF=1 @{0 599160 2}
# نواف -> term9915 Nt=31 TF=31 maxTF=1 @{0 599182 4}
# نوافذ -> term6093 Nt=1 TF=1 maxTF=1 @{0 599231 0}
# نوال -> term4754 Nt=2 TF=2 maxTF=1 @{0 599234 2}
# نوان -> term11413 Nt=1 TF=1 maxTF=1 @{0 599240 4}
# نواي -> term6898 Nt=2 TF=2 maxTF=1 @{0 599244 0}
# نوت -> term13979 Nt=2 TF=2 maxTF=1 @{0 599251 0}
# نوج -> term18493 Nt=2 TF=2 maxTF=1 @{0 599258 4}
# نوح -> term8082 Nt=1 TF=1 maxTF=1 @{0 599265 6}
# نود -> term5133 Nt=7 TF=7 maxTF=1 @{0 599269 0}
# نودع -> term1444 Nt=1 TF=1 maxTF=1 @{0 599281 4}
# نور -> term1894 Nt=179 TF=280 maxTF=3 @{0 599284 0}
# نورالد -> term10612 Nt=10 TF=10 maxTF=1 @{0 599514 1}
# نوران -> term20645 Nt=6 TF=6 maxTF=1 @{0 599530 5}
# نورت -> term7189 Nt=1 TF=1 maxTF=1 @{0 599539 5}
# نورس -> term18684 Nt=2 TF=2 maxTF=1 @{0 599542 7}
# نوروز -> term21611 Nt=4 TF=4 maxTF=1 @{0 599550 1}
# نوس -> term16151 Nt=6 TF=6 maxTF=1 @{0 599560 1}
# نوص -> term21285 Nt=1 TF=1 maxTF=1 @{0 599570 1}
# نوصل -> term16989 Nt=1 TF=1 maxTF=1 @{0 599574 1}
# نوضو -> term10479 Nt=1 TF=1 maxTF=1 @{0 599577 7}
# نوع -> term4562 Nt=63 TF=63 maxTF=1 @{0 599581 3}
# نوعيه -> term17542 Nt=16 TF=16 maxTF=1 @{0 599712 3}
# نوف -> term16346 Nt=1 TF=1 maxTF=1 @{0 599745 1}
# نوفيل -> term11771 Nt=1 TF=1 maxTF=1 @{0 599748 7}
# نوقع -> term2645 Nt=1 TF=1 maxTF=1 @{0 599752 3}
# نوقف -> term19996 Nt=3 TF=4 maxTF=2 @{0 599755 1}
# نوكامب -> term16164 Nt=1 TF=1 maxTF=1 @{0 599764 6}
# نوكل -> term19504 Nt=2 TF=2 maxTF=1 @{0 599768 4}
# نولد -> term14251 Nt=1 TF=1 maxTF=1 @{0 599774 6}
# نولوجيت -> term1689 Nt=1 TF=1 maxTF=1 @{0 599778 4}
# نوم -> term3452 Nt=18 TF=19 maxTF=2 @{0 599781 0}
# نومهمافاد -> term10652 Nt=1 TF=1 maxTF=1 @{0 599829 5}
# نون -> term11840 Nt=6 TF=6 maxTF=1 @{0 599833 1}
# نونو -> term6384 Nt=2 TF=2 maxTF=1 @{0 599851 7}
# نوه -> term23091 Nt=1 TF=1 maxTF=1 @{0 599858 3}
# نوو -> term10034 Nt=11 TF=11 maxTF=1 @{0 599862 3}
# نوويه -> term1691 Nt=1 TF=1 maxTF=1 @{0 599886 7}
# نوير -> term14851 Nt=26 TF=26 maxTF=1 @{0 599889 3}
# نويصر -> term17016 Nt=1 TF=1 maxTF=1 @{0 599931 1}
# ني -> term5648 Nt=8 TF=8 maxTF=1 @{0 599934 7}
# نيا -> term16873 Nt=1 TF=1 maxTF=1 @{0 599959 7}
# نياب -> term3304 Nt=14 TF=14 maxTF=1 @{0 599963 5}
# نيابقياد -> term23440 Nt=1 TF=1 maxTF=1 @{0 599995 3}
# نيابه -> term4671 Nt=127 TF=129 maxTF=2 @{0 599999 3}
# نيابيه -> term7583 Nt=8 TF=8 maxTF=1 @{0 600145 7}
# نياح -> term7838 Nt=1 TF=1 maxTF=1 @{0 600163 5}
# نيار -> term22196 Nt=1 TF=1 maxTF=1 @{0 600166 7}
# نياز -> term17968 Nt=2 TF=2 maxTF=1 @{0 600170 7}
# نياس -> term21341 Nt=1 TF=1 maxTF=1 @{0 600177 3}
# نيام -> term2445 Nt=12 TF=12 maxTF=1 @{0 600181 3}
# نياه -> term23299 Nt=1 TF=1 maxTF=1 @{0 600209 7}
# نيبال -> term12991 Nt=2 TF=3 maxTF=2 @{0 600213 7}
# نيت -> term16712 Nt=8 TF=8 maxTF=1 @{0 600219 4}
# نيجبري -> term15178 Nt=1 TF=1 maxTF=1 @{0 600232 2}
# نيجر -> term3885 Nt=5 TF=5 maxTF=1 @{0 600236 0}
# نيجري -> term6715 Nt=33 TF=35 maxTF=2 @{0 600244 2}
# نيجه -> term21258 Nt=1 TF=1 maxTF=1 @{0 600317 2}
# نيجيبري -> term12030 Nt=3 TF=3 maxTF=1 @{0 600321 2}
# نيجير -> term3221 Nt=173 TF=183 maxTF=2 @{0 600328 0}
# نيجيرب -> term15606 Nt=1 TF=1 maxTF=1 @{0 600565 0}
# نيجيرف -> term21911 Nt=5 TF=5 maxTF=1 @{0 600568 6}
# نيجيري -> term606 Nt=1154 TF=1264 maxTF=2 @{0 600582 4}
# نيجيرياتوقع -> term15218 Nt=1 TF=1 maxTF=1 @{0 601571 2}
# نيجيريه -> term7617 Nt=47 TF=51 maxTF=2 @{0 601575 0}
# نيحيري -> term14785 Nt=1 TF=1 maxTF=1 @{0 601644 4}
# نير -> term4312 Nt=10 TF=11 maxTF=2 @{0 601648 2}
# نيران -> term20544 Nt=3 TF=3 maxTF=1 @{0 601672 1}
# نيرد -> term9055 Nt=1 TF=1 maxTF=1 @{0 601681 5}
# نيروب -> term6713 Nt=2 TF=2 maxTF=1 @{0 601685 1}
# نيروها -> term21531 Nt=1 TF=1 maxTF=1 @{0 601692 1}
# نيز -> term21529 Nt=1 TF=1 maxTF=1 @{0 601696 1}
# نيس -> term11671 Nt=3 TF=3 maxTF=1 @{0 601700 1}
# نيسان -> term10152 Nt=9 TF=9 maxTF=1 @{0 601709 5}
# نيسو -> term18686 Nt=1 TF=1 maxTF=1 @{0 601729 3}
# نيش -> term14278 Nt=6 TF=6 maxTF=1 @{0 601733 1}
# نيشمور -> term20355 Nt=1 TF=1 maxTF=1 @{0 601746 7}
# نيشيمور -> term6188 Nt=2 TF=2 maxTF=1 @{0 601750 7}
# نيض -> term16991 Nt=1 TF=1 maxTF=1 @{0 601757 7}
# نيفي -> term8943 Nt=1 TF=1 maxTF=1 @{0 601761 5}
# نيفيز -> term23297 Nt=2 TF=3 maxTF=2 @{0 601765 1}
# نيفين -> term536 Nt=2 TF=2 maxTF=1 @{0 601771 0}
# نيك -> term5923 Nt=3 TF=3 maxTF=1 @{0 601775 2}
# نيكرز -> term8946 Nt=1 TF=1 maxTF=1 @{0 601785 2}
# نيكس -> term3566 Nt=1 TF=1 maxTF=1 @{0 601788 6}
# نيل -> term3915 Nt=28 TF=28 maxTF=1 @{0 601791 4}
# نيله -> term23904 Nt=1 TF=1 maxTF=1 @{0 601853 0}
# نيمااار -> term16085 Nt=1 TF=1 maxTF=1 @{0 601857 0}
# نيماار -> term12278 Nt=1 TF=1 maxTF=1 @{0 601860 6}
# نيمار -> term1014 Nt=27 TF=27 maxTF=1 @{0 601864 2}
# نيمين -> term17350 Nt=1 TF=1 maxTF=1 @{0 601902 2}
# نين -> term23339 Nt=2 TF=2 maxTF=1 @{0 601906 0}
# نينجا -> term21617 Nt=1 TF=1 maxTF=1 @{0 601912 4}
# نينو -> term10798 Nt=51 TF=51 maxTF=1 @{0 601916 4}
# نيه -> term5606 Nt=10 TF=10 maxTF=1 @{0 602012 0}
# نيهتبد -> term19405 Nt=1 TF=1 maxTF=1 @{0 602040 4}
# نيو -> term3854 Nt=10 TF=10 maxTF=1 @{0 602044 2}
# نيور -> term16610 Nt=1 TF=1 maxTF=1 @{0 602066 2}
# نيوز -> term1091 Nt=293 TF=297 maxTF=2 @{0 602070 0}
# نيوزعرب -> term13775 Nt=1 TF=1 maxTF=1 @{0 602551 2}
# نيوزيلند -> term22059 Nt=5 TF=5 maxTF=1 @{0 602555 0}
# نيوس -> term17078 Nt=1 TF=1 maxTF=1 @{0 602567 0}
# نيوكاسل -> term5372 Nt=6 TF=6 maxTF=1 @{0 602570 6}
# نيوهرايز -> term14030 Nt=1 TF=1 maxTF=1 @{0 602586 4}
# نيويور -> term81 Nt=696 TF=705 maxTF=2 @{0 602590 2}
# نيويورك2001 -> term24838 Nt=1 TF=1 maxTF=1 @{0 602963 3}
# نييجيري -> term14691 Nt=6 TF=6 maxTF=1 @{0 602967 3}
# نييوز -> term4940 Nt=4 TF=4 maxTF=1 @{0 602978 3}
# نيييله -> term11673 Nt=1 TF=1 maxTF=1 @{0 602985 1}
# هء -> term9273 Nt=4 TF=6 maxTF=3 @{0 602988 5}
# هءهءهءهءهءهءهء -> term19700 Nt=1 TF=1 maxTF=1 @{0 603000 7}
# ها -> term3123 Nt=19 TF=20 maxTF=2 @{0 603004 7}
# هاء -> term8819 Nt=1 TF=1 maxTF=1 @{0 603056 4}
# هاءل -> term10061 Nt=8 TF=9 maxTF=2 @{0 603060 0}
# هاءم -> term12465 Nt=1 TF=1 maxTF=1 @{0 603085 3}
# هاا -> term15438 Nt=2 TF=2 maxTF=1 @{0 603088 7}
# هااا -> term4495 Nt=2 TF=2 maxTF=1 @{0 603095 7}
# هاااللرررسوووم -> term15353 Nt=1 TF=1 maxTF=1 @{0 603102 1}
# هااام -> term4518 Nt=3 TF=3 maxTF=1 @{0 603105 7}
# هاات -> term19245 Nt=1 TF=1 maxTF=1 @{0 603116 3}
# هاالتغريدا -> term17186 Nt=1 TF=1 maxTF=1 @{0 603120 1}
# هاب -> term3857 Nt=6 TF=6 maxTF=1 @{0 603123 7}
# هابد -> term10681 Nt=20 TF=20 maxTF=1 @{0 603142 3}
# هابط -> term9154 Nt=9 TF=9 maxTF=1 @{0 603155 7}
# هات -> term8019 Nt=12 TF=14 maxTF=2 @{0 603177 1}
# هاتجمع -> term7256 Nt=3 TF=3 maxTF=1 @{0 603207 5}
# هاتر -> term7667 Nt=2 TF=2 maxTF=1 @{0 603213 3}
# هاتريك -> term17046 Nt=1 TF=1 maxTF=1 @{0 603220 3}
# هاتف -> term14091 Nt=15 TF=15 maxTF=1 @{0 603224 1}
# هاتفي -> term9791 Nt=4 TF=4 maxTF=1 @{0 603258 5}
# هاتفيه -> term11541 Nt=4 TF=8 maxTF=2 @{0 603271 5}
# هاتن -> term22949 Nt=1 TF=1 maxTF=1 @{0 603277 5}
# هاتو -> term16926 Nt=3 TF=3 maxTF=1 @{0 603281 5}
# هاتول -> term6120 Nt=1 TF=1 maxTF=1 @{0 603292 1}
# هاجد -> term16141 Nt=2 TF=2 maxTF=1 @{0 603295 3}
# هاجر -> term3726 Nt=4 TF=4 maxTF=1 @{0 603302 7}
# هاجرحبيب -> term18857 Nt=1 TF=1 maxTF=1 @{0 603316 1}
# هاجم -> term3636 Nt=59 TF=59 maxTF=1 @{0 603319 7}
# هاد -> term1538 Nt=1035 TF=1103 maxTF=2 @{0 603413 7}
# هادء -> term20088 Nt=3 TF=3 maxTF=1 @{0 604089 1}
# هادءه -> term10955 Nt=2 TF=2 maxTF=1 @{0 604099 3}
# هادرل -> term21409 Nt=1 TF=1 maxTF=1 @{0 604106 5}
# هاذ -> term209 Nt=14 TF=15 maxTF=2 @{0 604110 5}
# هاذان -> term11180 Nt=3 TF=3 maxTF=1 @{0 604149 2}
# هاذم -> term22491 Nt=1 TF=1 maxTF=1 @{0 604155 6}
# هاذوم -> term22521 Nt=1 TF=1 maxTF=1 @{0 604159 6}
# هار -> term15417 Nt=2 TF=2 maxTF=1 @{0 604163 6}
# هارا -> term5724 Nt=3 TF=3 maxTF=1 @{0 604170 6}
# هارب -> term5450 Nt=8 TF=8 maxTF=1 @{0 604179 2}
# هارتس -> term3848 Nt=8 TF=8 maxTF=1 @{0 604199 2}
# هارثه -> term13287 Nt=23 TF=25 maxTF=2 @{0 604215 6}
# هارد -> term13009 Nt=16 TF=16 maxTF=1 @{0 604259 0}
# هاردل -> term13027 Nt=47 TF=48 maxTF=2 @{0 604289 4}
# هارون -> term20953 Nt=1 TF=1 maxTF=1 @{0 604363 1}
# هازارد -> term12395 Nt=4 TF=4 maxTF=1 @{0 604367 1}
# هاسب -> term21141 Nt=2 TF=2 maxTF=1 @{0 604380 1}
# هاسعد -> term24099 Nt=1 TF=1 maxTF=1 @{0 604386 7}
# هاسيل -> term24079 Nt=1 TF=1 maxTF=1 @{0 604390 7}
# هاش -> term15536 Nt=2 TF=2 maxTF=1 @{0 604394 7}
# هاشتااج -> term15747 Nt=1 TF=1 maxTF=1 @{0 604402 3}
# هاشتاج -> term10554 Nt=7 TF=7 maxTF=1 @{0 604406 1}
# هاشتاغ -> term15518 Nt=3 TF=3 maxTF=1 @{0 604426 7}
# هاشتاق -> term1332 Nt=5 TF=5 maxTF=1 @{0 604437 3}
# هاشتاقا -> term13755 Nt=2 TF=2 maxTF=1 @{0 604452 7}
# هاشم -> term708 Nt=4 TF=4 maxTF=1 @{0 604459 7}
# هاض -> term24916 Nt=1 TF=1 maxTF=1 @{0 604472 3}
# هاظ -> term19650 Nt=1 TF=1 maxTF=1 @{0 604476 3}
# هافيلانج -> term17917 Nt=1 TF=1 maxTF=1 @{0 604480 3}
# هاقد -> term19839 Nt=1 TF=1 maxTF=1 @{0 604484 1}
# هاكر -> term16999 Nt=9 TF=9 maxTF=1 @{0 604488 1}
# هاكرز -> term781 Nt=10 TF=11 maxTF=2 @{0 604507 1}
# هاكورد -> term7040 Nt=1 TF=1 maxTF=1 @{0 604529 2}
# هال -> term5892 Nt=3 TF=3 maxTF=1 @{0 604532 4}
# هالاتفاق -> term18949 Nt=1 TF=1 maxTF=1 @{0 604542 6}
# هالاثن -> term14484 Nt=2 TF=2 maxTF=1 @{0 604546 4}
# هالاحداث -> term11693 Nt=1 TF=1 maxTF=1 @{0 604551 6}
# هالاسبوع -> term17766 Nt=1 TF=1 maxTF=1 @{0 604555 2}
# هالاسطورت -> term15751 Nt=1 TF=1 maxTF=1 @{0 604559 0}
# هالاسم -> term13124 Nt=1 TF=1 maxTF=1 @{0 604562 6}
# هالاسيل -> term23947 Nt=1 TF=1 maxTF=1 @{0 604566 4}
# هالانتماء -> term19594 Nt=1 TF=1 maxTF=1 @{0 604570 4}
# هالانوث -> term6140 Nt=1 TF=1 maxTF=1 @{0 604574 2}
# هالايام -> term13237 Nt=1 TF=1 maxTF=1 @{0 604577 4}
# هالبرد -> term10171 Nt=1 TF=1 maxTF=1 @{0 604581 2}
# هالبسم -> term16163 Nt=1 TF=1 maxTF=1 @{0 604584 6}
# هالبطول -> term13058 Nt=1 TF=1 maxTF=1 @{0 604588 4}
# هالبعد -> term16128 Nt=2 TF=2 maxTF=1 @{0 604592 2}
# هالبلد -> term16718 Nt=1 TF=1 maxTF=1 @{0 604599 0}
# هالبنا -> term10519 Nt=1 TF=1 maxTF=1 @{0 604602 6}
# هالتعابير -> term15071 Nt=1 TF=1 maxTF=1 @{0 604606 2}
# هالثلاث -> term17100 Nt=1 TF=1 maxTF=1 @{0 604610 0}
# هالثناء -> term14552 Nt=1 TF=1 maxTF=1 @{0 604613 6}
# هالجاءز -> term16896 Nt=1 TF=1 maxTF=1 @{0 604617 4}
# هالجمال -> term13790 Nt=1 TF=1 maxTF=1 @{0 604621 2}
# هالح -> term12703 Nt=4 TF=4 maxTF=1 @{0 604625 0}
# هالحس -> term19596 Nt=1 TF=1 maxTF=1 @{0 604638 6}
# هالحساب -> term13511 Nt=2 TF=2 maxTF=1 @{0 604642 4}
# هالحظ -> term19191 Nt=1 TF=1 maxTF=1 @{0 604649 4}
# هالحل -> term6259 Nt=1 TF=1 maxTF=1 @{0 604653 2}
# هالحمار -> term18222 Nt=1 TF=1 maxTF=1 @{0 604656 4}
# هالخبر -> term6905 Nt=2 TF=2 maxTF=1 @{0 604660 2}
# هالخطاب -> term24395 Nt=1 TF=1 maxTF=1 @{0 604667 4}
# هالخوف -> term19193 Nt=1 TF=1 maxTF=1 @{0 604671 4}
# هالر -> term12802 Nt=1 TF=1 maxTF=1 @{0 604675 2}
# هالرابط -> term16634 Nt=1 TF=1 maxTF=1 @{0 604679 0}
# هالرياض -> term12882 Nt=1 TF=1 maxTF=1 @{0 604682 6}
# هالزلايب -> term16673 Nt=1 TF=1 maxTF=1 @{0 604686 4}
# هالس -> term6739 Nt=4 TF=4 maxTF=1 @{0 604690 2}
# هالسرع -> term13604 Nt=1 TF=1 maxTF=1 @{0 604703 6}
# هالسمستر -> term17861 Nt=1 TF=1 maxTF=1 @{0 604707 4}
# هالش -> term4333 Nt=3 TF=3 maxTF=1 @{0 604711 2}
# هالشغل -> term18165 Nt=1 TF=1 maxTF=1 @{0 604721 2}
# هالشيء -> term21054 Nt=1 TF=1 maxTF=1 @{0 604725 0}
# هالصباح -> term15358 Nt=1 TF=1 maxTF=1 @{0 604729 0}
# هالصبح -> term17758 Nt=1 TF=1 maxTF=1 @{0 604732 6}
# هالصور -> term24584 Nt=1 TF=1 maxTF=1 @{0 604736 4}
# هالضغط -> term13189 Nt=1 TF=1 maxTF=1 @{0 604740 4}
# هالعقل -> term18324 Nt=1 TF=1 maxTF=1 @{0 604744 2}
# هالعمل -> term11025 Nt=1 TF=1 maxTF=1 @{0 604748 0}
# هالفتر -> term24852 Nt=1 TF=1 maxTF=1 @{0 604751 4}
# هالفرص -> term13076 Nt=1 TF=1 maxTF=1 @{0 604755 4}
# هالفريق -> term13118 Nt=1 TF=1 maxTF=1 @{0 604759 2}
# هالفلم -> term23311 Nt=1 TF=1 maxTF=1 @{0 604763 0}
# هالفوز -> term19701 Nt=1 TF=1 maxTF=1 @{0 604767 0}
# هالق -> term23626 Nt=1 TF=1 maxTF=1 @{0 604771 0}
# هالقان -> term9047 Nt=1 TF=1 maxTF=1 @{0 604775 0}
# هالقد -> term2901 Nt=2 TF=2 maxTF=1 @{0 604778 4}
# هالقلب -> term21552 Nt=1 TF=1 maxTF=1 @{0 604785 2}
# هالك -> term10997 Nt=1 TF=1 maxTF=1 @{0 604789 2}
# هالكتاكي -> term20409 Nt=1 TF=1 maxTF=1 @{0 604792 6}
# هالكلام -> term14496 Nt=3 TF=3 maxTF=1 @{0 604796 6}
# هاللاعب -> term17856 Nt=1 TF=2 maxTF=2 @{0 604806 6}
# هاللعب -> term12846 Nt=2 TF=2 maxTF=1 @{0 604810 5}
# هاللقب -> term8543 Nt=1 TF=1 maxTF=1 @{0 604818 1}
# هالمر -> term19948 Nt=3 TF=3 maxTF=1 @{0 604821 5}
# هالمرحل -> term21406 Nt=2 TF=2 maxTF=1 @{0 604831 1}
# هالمز -> term8200 Nt=1 TF=1 maxTF=1 @{0 604836 5}
# هالمسءول -> term16842 Nt=1 TF=1 maxTF=1 @{0 604839 7}
# هالمستو -> term13075 Nt=1 TF=1 maxTF=1 @{0 604843 5}
# هالمشاريع -> term6619 Nt=1 TF=1 maxTF=1 @{0 604847 3}
# هالمنتخب -> term12788 Nt=5 TF=5 maxTF=1 @{0 604850 5}
# هالمنظر -> term15783 Nt=2 TF=2 maxTF=1 @{0 604865 3}
# هالناد -> term21991 Nt=1 TF=1 maxTF=1 @{0 604871 5}
# هالنقط -> term17219 Nt=4 TF=4 maxTF=1 @{0 604875 5}
# هالنوب -> term23449 Nt=1 TF=1 maxTF=1 @{0 604885 7}
# هالنوع -> term17827 Nt=1 TF=1 maxTF=1 @{0 604889 7}
# هالو -> term7846 Nt=2 TF=2 maxTF=1 @{0 604893 5}
# هالوج -> term24365 Nt=1 TF=1 maxTF=1 @{0 604900 7}
# هالورق -> term23175 Nt=1 TF=1 maxTF=1 @{0 604904 7}
# هالوسط -> term16086 Nt=1 TF=1 maxTF=1 @{0 604908 7}
# هالوق -> term9434 Nt=2 TF=2 maxTF=1 @{0 604912 5}
# هاليوم -> term6877 Nt=3 TF=3 maxTF=1 @{0 604919 7}
# هام -> term1281 Nt=46 TF=46 maxTF=1 @{0 604930 1}
# هامب -> term15537 Nt=1 TF=1 maxTF=1 @{0 605027 5}
# هامبرغر -> term15512 Nt=2 TF=2 maxTF=1 @{0 605031 3}
# هامبورج -> term15446 Nt=8 TF=8 maxTF=1 @{0 605037 1}
# هامبورغ -> term15409 Nt=116 TF=116 maxTF=1 @{0 605052 3}
# هامبورغر -> term15509 Nt=11 TF=11 maxTF=1 @{0 605132 5}
# هامد -> term7403 Nt=2 TF=2 maxTF=1 @{0 605149 3}
# هامر -> term12191 Nt=5 TF=5 maxTF=1 @{0 605153 5}
# هامش -> term13641 Nt=4 TF=4 maxTF=1 @{0 605165 5}
# هامه -> term17102 Nt=1 TF=1 maxTF=1 @{0 605177 3}
# هان -> term17418 Nt=8 TF=8 maxTF=1 @{0 605181 1}
# هانس -> term18356 Nt=1 TF=1 maxTF=1 @{0 605198 7}
# هاه -> term4580 Nt=12 TF=13 maxTF=2 @{0 605202 5}
# هاهاهاع -> term7507 Nt=1 TF=1 maxTF=1 @{0 605237 0}
# هاهم -> term22539 Nt=1 TF=1 maxTF=1 @{0 605240 2}
# هاهو -> term21581 Nt=1 TF=1 maxTF=1 @{0 605244 2}
# هاو -> term12726 Nt=3 TF=3 maxTF=1 @{0 605248 2}
# هاوار -> term9461 Nt=1 TF=1 maxTF=1 @{0 605258 6}
# هاور -> term23656 Nt=1 TF=1 maxTF=1 @{0 605262 2}
# هاوس -> term19080 Nt=8 TF=8 maxTF=1 @{0 605266 2}
# هاون -> term11503 Nt=33 TF=33 maxTF=1 @{0 605288 2}
# هاويه -> term3539 Nt=5 TF=5 maxTF=1 @{0 605338 6}
# هايبق -> term20296 Nt=1 TF=1 maxTF=1 @{0 605352 6}
# هايحصل -> term17432 Nt=1 TF=1 maxTF=1 @{0 605356 6}
# هايسيب -> term23979 Nt=1 TF=1 maxTF=1 @{0 605360 4}
# هايطول -> term24780 Nt=1 TF=1 maxTF=1 @{0 605364 4}
# هايعرف -> term24781 Nt=1 TF=1 maxTF=1 @{0 605368 4}
# هايعمل -> term15881 Nt=2 TF=2 maxTF=1 @{0 605372 4}
# هايفرض -> term6746 Nt=1 TF=1 maxTF=1 @{0 605379 6}
# هايقدر -> term24778 Nt=1 TF=1 maxTF=1 @{0 605383 0}
# هايك -> term24059 Nt=1 TF=1 maxTF=1 @{0 605387 0}
# هايل -> term10721 Nt=1 TF=1 maxTF=1 @{0 605391 0}
# هايلازق -> term10693 Nt=1 TF=1 maxTF=1 @{0 605394 4}
# هايلكس -> term12094 Nt=1 TF=1 maxTF=1 @{0 605398 0}
# هايم -> term22236 Nt=1 TF=1 maxTF=1 @{0 605401 4}
# هايو -> term11654 Nt=1 TF=1 maxTF=1 @{0 605405 4}
# هاييج -> term12141 Nt=1 TF=1 maxTF=1 @{0 605409 0}
# هبا -> term20492 Nt=2 TF=2 maxTF=1 @{0 605412 4}
# هباريه -> term24540 Nt=2 TF=2 maxTF=1 @{0 605420 0}
# هبال -> term12352 Nt=1 TF=1 maxTF=1 @{0 605426 6}
# هبان -> term24783 Nt=1 TF=1 maxTF=1 @{0 605430 2}
# هبايب -> term8230 Nt=1 TF=1 maxTF=1 @{0 605434 2}
# هبت -> term4919 Nt=1 TF=1 maxTF=1 @{0 605437 4}
# هبد -> term17826 Nt=1 TF=1 maxTF=1 @{0 605440 4}
# هبدو -> term14120 Nt=1 TF=1 maxTF=1 @{0 605444 2}
# هبره -> term22408 Nt=1 TF=1 maxTF=1 @{0 605448 0}
# هبط -> term1722 Nt=3 TF=3 maxTF=1 @{0 605452 0}
# هبل -> term13350 Nt=8 TF=8 maxTF=1 @{0 605460 0}
# هبله -> term24862 Nt=1 TF=1 maxTF=1 @{0 605480 6}
# هبه -> term10014 Nt=4 TF=4 maxTF=1 @{0 605484 6}
# هبو -> term19869 Nt=1 TF=1 maxTF=1 @{0 605498 2}
# هبوب -> term20215 Nt=2 TF=2 maxTF=1 @{0 605502 2}
# هبوط -> term6181 Nt=30 TF=30 maxTF=1 @{0 605509 2}
# هتا -> term24285 Nt=1 TF=1 maxTF=1 @{0 605544 2}
# هتافا -> term1946 Nt=10 TF=10 maxTF=1 @{0 605548 2}
# هتان -> term15621 Nt=1 TF=1 maxTF=1 @{0 605564 4}
# هتبتد -> term23952 Nt=1 TF=1 maxTF=1 @{0 605568 2}
# هتبق -> term13682 Nt=3 TF=3 maxTF=1 @{0 605572 2}
# هتتحول -> term22098 Nt=1 TF=1 maxTF=1 @{0 605582 0}
# هتتعامل -> term10675 Nt=1 TF=1 maxTF=1 @{0 605586 0}
# هتتلب -> term12553 Nt=1 TF=1 maxTF=1 @{0 605589 4}
# هتجاهد -> term23698 Nt=1 TF=2 maxTF=2 @{0 605593 2}
# هتجن -> term9600 Nt=1 TF=1 maxTF=1 @{0 605597 3}
# هتحصل -> term10007 Nt=2 TF=2 maxTF=1 @{0 605600 7}
# هتحط -> term23493 Nt=1 TF=1 maxTF=1 @{0 605608 3}
# هتخلص -> term23766 Nt=1 TF=1 maxTF=1 @{0 605612 3}
# هتدفع -> term20112 Nt=3 TF=3 maxTF=1 @{0 605616 3}
# هترد -> term23014 Nt=1 TF=1 maxTF=1 @{0 605624 5}
# هتستعبط -> term24941 Nt=1 TF=1 maxTF=1 @{0 605628 5}
# هتسيطر -> term10008 Nt=1 TF=1 maxTF=1 @{0 605632 5}
# هتضرب -> term2240 Nt=1 TF=1 maxTF=1 @{0 605636 1}
# هتطلب -> term13492 Nt=1 TF=1 maxTF=1 @{0 605638 5}
# هتعرض -> term5165 Nt=1 TF=1 maxTF=1 @{0 605642 3}
# هتعرف -> term13344 Nt=1 TF=1 maxTF=1 @{0 605645 3}
# هتعمل -> term13967 Nt=1 TF=1 maxTF=1 @{0 605649 1}
# هتعيش -> term9346 Nt=1 TF=1 maxTF=1 @{0 605652 7}
# هتف -> term10499 Nt=7 TF=7 maxTF=1 @{0 605656 3}
# هتفرق -> term3315 Nt=1 TF=1 maxTF=1 @{0 605671 7}
# هتفشخ -> term10570 Nt=1 TF=1 maxTF=1 @{0 605674 5}
# هتفوز -> term13852 Nt=1 TF=1 maxTF=1 @{0 605678 1}
# هتقتل -> term14036 Nt=1 TF=1 maxTF=1 @{0 605681 7}
# هتك -> term13135 Nt=1 TF=1 maxTF=1 @{0 605685 5}
# هتكسب -> term23492 Nt=1 TF=1 maxTF=1 @{0 605689 3}
# هتكون -> term23929 Nt=1 TF=1 maxTF=1 @{0 605693 3}
# هتلاق -> term17476 Nt=1 TF=1 maxTF=1 @{0 605697 3}
# هتلر -> term22749 Nt=1 TF=1 maxTF=1 @{0 605701 1}
# هتلعب -> term12554 Nt=1 TF=1 maxTF=1 @{0 605705 1}
# هتوقف -> term13968 Nt=1 TF=1 maxTF=1 @{0 605708 7}
# هجانه -> term5865 Nt=1 TF=1 maxTF=1 @{0 605712 5}
# هجد -> term19651 Nt=1 TF=1 maxTF=1 @{0 605715 5}
# هجر -> term6038 Nt=32 TF=32 maxTF=1 @{0 605719 5}
# هجره -> term9851 Nt=3 TF=3 maxTF=1 @{0 605758 3}
# هجرو -> term16985 Nt=1 TF=1 maxTF=1 @{0 605768 7}
# هجزم -> term10839 Nt=2 TF=2 maxTF=1 @{0 605772 5}
# هجم -> term5311 Nt=49 TF=49 maxTF=1 @{0 605776 7}
# هجما -> term3266 Nt=670 TF=726 maxTF=2 @{0 605874 3}
# هجمت -> term23376 Nt=1 TF=1 maxTF=1 @{0 606465 1}
# هجمه -> term14763 Nt=1 TF=1 maxTF=1 @{0 606469 1}
# هجمو -> term10409 Nt=3 TF=3 maxTF=1 @{0 606472 7}
# هجموم -> term13284 Nt=1 TF=1 maxTF=1 @{0 606482 1}
# هجو -> term8595 Nt=20 TF=20 maxTF=1 @{0 606485 7}
# هجوم -> term780 Nt=5325 TF=6024 maxTF=3 @{0 606506 7}
# هجوما -> term11804 Nt=6 TF=6 maxTF=1 @{0 609798 6}
# هجوميه -> term7755 Nt=4 TF=4 maxTF=1 @{0 609812 6}
# هجوميهالت -> term7881 Nt=1 TF=1 maxTF=1 @{0 609819 4}
# هجووم -> term14306 Nt=1 TF=1 maxTF=1 @{0 609822 6}
# هجيب -> term15332 Nt=1 TF=1 maxTF=1 @{0 609826 4}
# هحما -> term24117 Nt=1 TF=1 maxTF=1 @{0 609830 2}
# هحوم -> term10398 Nt=3 TF=3 maxTF=1 @{0 609834 2}
# هد -> term6985 Nt=25 TF=33 maxTF=2 @{0 609843 6}
# هدا -> term13360 Nt=7 TF=7 maxTF=1 @{0 609897 0}
# هداعش -> term20515 Nt=1 TF=1 maxTF=1 @{0 609917 2}
# هداف -> term13210 Nt=7 TF=8 maxTF=2 @{0 609921 2}
# هدالشقير -> term3336 Nt=1 TF=1 maxTF=1 @{0 609943 5}
# هدالعتيب -> term19697 Nt=3 TF=3 maxTF=1 @{0 609946 3}
# هداهيد -> term2515 Nt=8 TF=8 maxTF=1 @{0 609955 7}
# هداي -> term293 Nt=3 TF=3 maxTF=1 @{0 609970 1}
# هدت -> term10912 Nt=1 TF=1 maxTF=1 @{0 609978 7}
# هدخل -> term19546 Nt=1 TF=2 maxTF=2 @{0 609982 3}
# هدد -> term1850 Nt=15 TF=15 maxTF=1 @{0 609986 2}
# هددو -> term10444 Nt=1 TF=1 maxTF=1 @{0 610026 4}
# هدر -> term18454 Nt=2 TF=2 maxTF=1 @{0 610030 0}
# هدرج -> term12612 Nt=1 TF=1 maxTF=1 @{0 610037 2}
# هدف -> term2367 Nt=424 TF=442 maxTF=2 @{0 610041 0}
# هدفين -> term11210 Nt=17 TF=17 maxTF=1 @{0 610527 6}
# هدل -> term2427 Nt=3 TF=3 maxTF=1 @{0 610567 6}
# هدم -> term3998 Nt=11 TF=12 maxTF=2 @{0 610578 0}
# هدن -> term19106 Nt=5 TF=5 maxTF=1 @{0 610602 1}
# هده -> term22435 Nt=2 TF=2 maxTF=1 @{0 610612 5}
# هدو -> term10947 Nt=2 TF=2 maxTF=1 @{0 610618 7}
# هدوء -> term14176 Nt=42 TF=46 maxTF=2 @{0 610625 7}
# هدومك -> term17499 Nt=2 TF=2 maxTF=1 @{0 610695 1}
# هدي -> term5952 Nt=11 TF=11 maxTF=1 @{0 610700 1}
# هديل -> term9062 Nt=1 TF=1 maxTF=1 @{0 610732 1}
# هذ -> term6480 Nt=2 TF=3 maxTF=2 @{0 610735 5}
# هذا -> term15586 Nt=21 TF=21 maxTF=1 @{0 610743 0}
# هذاء -> term21345 Nt=1 TF=1 maxTF=1 @{0 610785 2}
# هذاالمنتج -> term10631 Nt=1 TF=1 maxTF=1 @{0 610789 2}
# هذال -> term24527 Nt=38 TF=55 maxTF=3 @{0 610792 6}
# هذالتمالترحيل -> term24552 Nt=1 TF=1 maxTF=1 @{0 610840 3}
# هذامنظر -> term2906 Nt=1 TF=1 maxTF=1 @{0 610844 3}
# هذه -> term10377 Nt=4 TF=4 maxTF=1 @{0 610847 1}
# هذول -> term2426 Nt=4 TF=4 maxTF=1 @{0 610859 7}
# هذي -> term15607 Nt=2 TF=2 maxTF=1 @{0 610872 1}
# هذيل -> term23584 Nt=1 TF=1 maxTF=1 @{0 610879 5}
# هر -> term23856 Nt=1 TF=1 maxTF=1 @{0 610883 5}
# هراء -> term12399 Nt=2 TF=2 maxTF=1 @{0 610887 5}
# هران -> term5880 Nt=1 TF=1 maxTF=1 @{0 610894 1}
# هرب -> term7108 Nt=16 TF=18 maxTF=2 @{0 610897 1}
# هربج -> term21358 Nt=3 TF=5 maxTF=2 @{0 610938 7}
# هرتسوغ -> term2149 Nt=1 TF=1 maxTF=1 @{0 610948 7}
# هرج -> term21841 Nt=6 TF=6 maxTF=1 @{0 610951 3}
# هردل -> term13096 Nt=2 TF=2 maxTF=1 @{0 610965 5}
# هررماس -> term12672 Nt=1 TF=1 maxTF=1 @{0 610972 7}
# هرف -> term9223 Nt=1 TF=1 maxTF=1 @{0 610976 5}
# هرم -> term4315 Nt=17 TF=18 maxTF=2 @{0 610980 1}
# هرمل -> term20493 Nt=1 TF=1 maxTF=1 @{0 611018 6}
# هروب -> term2487 Nt=44 TF=45 maxTF=2 @{0 611022 6}
# هروح -> term12548 Nt=1 TF=1 maxTF=1 @{0 611107 3}
# هري -> term13382 Nt=1 TF=1 maxTF=1 @{0 611111 1}
# هرير -> term15983 Nt=4 TF=4 maxTF=1 @{0 611114 7}
# هز -> term2224 Nt=72 TF=74 maxTF=2 @{0 611125 7}
# هزء -> term17073 Nt=1 TF=1 maxTF=1 @{0 611231 5}
# هزا -> term15185 Nt=5 TF=5 maxTF=1 @{0 611235 3}
# هزاءم -> term19257 Nt=6 TF=6 maxTF=1 @{0 611246 5}
# هزار -> term24350 Nt=1 TF=1 maxTF=1 @{0 611265 3}
# هزاز -> term13277 Nt=41 TF=44 maxTF=2 @{0 611269 3}
# هزاع -> term16749 Nt=2 TF=2 maxTF=1 @{0 611328 4}
# هزبر -> term11812 Nt=2 TF=2 maxTF=1 @{0 611335 2}
# هزت -> term8515 Nt=11 TF=12 maxTF=2 @{0 611342 4}
# هزل -> term664 Nt=6 TF=6 maxTF=1 @{0 611369 5}
# هزليه -> term23436 Nt=2 TF=2 maxTF=1 @{0 611388 1}
# هزم -> term7214 Nt=14 TF=14 maxTF=1 @{0 611395 1}
# هزه -> term18879 Nt=1 TF=1 maxTF=1 @{0 611430 7}
# هزيل -> term12874 Nt=2 TF=2 maxTF=1 @{0 611434 5}
# هزيم -> term6578 Nt=40 TF=41 maxTF=2 @{0 611440 7}
# هزيمه -> term13264 Nt=17 TF=17 maxTF=1 @{0 611517 0}
# هسا -> term18957 Nt=2 TF=2 maxTF=1 @{0 611550 2}
# هسافر -> term9604 Nt=1 TF=1 maxTF=1 @{0 611557 0}
# هسب -> term18648 Nt=1 TF=1 maxTF=1 @{0 611560 4}
# هسبريس -> term18831 Nt=1 TF=1 maxTF=1 @{0 611564 2}
# هستكنيص -> term8846 Nt=1 TF=1 maxTF=1 @{0 611568 0}
# هسك -> term12398 Nt=1 TF=1 maxTF=1 @{0 611571 4}
# هسه -> term24180 Nt=1 TF=1 maxTF=1 @{0 611575 0}
# هسيب -> term8023 Nt=1 TF=1 maxTF=1 @{0 611579 0}
# هش -> term18270 Nt=2 TF=2 maxTF=1 @{0 611582 2}
# هشار -> term10823 Nt=1 TF=1 maxTF=1 @{0 611589 0}
# هشاغا -> term19587 Nt=1 TF=1 maxTF=1 @{0 611592 4}
# هشام -> term3263 Nt=7 TF=7 maxTF=1 @{0 611596 2}
# هشتاق -> term9497 Nt=3 TF=4 maxTF=2 @{0 611613 2}
# هشه -> term20371 Nt=1 TF=1 maxTF=1 @{0 611623 7}
# هصور -> term7563 Nt=1 TF=1 maxTF=1 @{0 611627 7}
# هضب -> term21767 Nt=25 TF=25 maxTF=1 @{0 611631 1}
# هطل -> term23965 Nt=1 TF=1 maxTF=1 @{0 611672 7}
# هظب -> term24942 Nt=1 TF=1 maxTF=1 @{0 611676 7}
# هعمل -> term18689 Nt=2 TF=2 maxTF=1 @{0 611680 7}
# هفال -> term21239 Nt=1 TF=1 maxTF=1 @{0 611688 1}
# هفوا -> term19715 Nt=1 TF=1 maxTF=1 @{0 611692 1}
# هفوف -> term14268 Nt=1 TF=1 maxTF=1 @{0 611696 1}
# هك -> term9256 Nt=5 TF=6 maxTF=2 @{0 611699 7}
# هكا -> term3100 Nt=1 TF=1 maxTF=1 @{0 611716 4}
# هكار -> term22033 Nt=3 TF=3 maxTF=1 @{0 611719 2}
# هكذ -> term7732 Nt=3 TF=4 maxTF=2 @{0 611725 0}
# هكر -> term573 Nt=11 TF=12 maxTF=2 @{0 611735 3}
# هكرز -> term15673 Nt=2 TF=2 maxTF=1 @{0 611763 2}
# هكز -> term7029 Nt=1 TF=1 maxTF=1 @{0 611769 4}
# هل -> term19302 Nt=1 TF=1 maxTF=1 @{0 611772 6}
# هلا -> term3290 Nt=18 TF=18 maxTF=1 @{0 611776 4}
# هلال -> term494 Nt=128 TF=137 maxTF=2 @{0 611824 2}
# هلب -> term22401 Nt=1 TF=1 maxTF=1 @{0 612042 7}
# هلباو -> term18033 Nt=1 TF=1 maxTF=1 @{0 612046 7}
# هلببب -> term22728 Nt=1 TF=1 maxTF=1 @{0 612050 5}
# هلتا -> term21884 Nt=1 TF=1 maxTF=1 @{0 612054 5}
# هلتون -> term22454 Nt=1 TF=1 maxTF=1 @{0 612058 5}
# هلخبر -> term15796 Nt=1 TF=1 maxTF=1 @{0 612062 5}
# هلز -> term21432 Nt=1 TF=1 maxTF=1 @{0 612066 3}
# هلع -> term22970 Nt=1 TF=1 maxTF=1 @{0 612070 3}
# هلق -> term6066 Nt=1 TF=1 maxTF=1 @{0 612074 3}
# هلقلقلقلق -> term17514 Nt=2 TF=2 maxTF=1 @{0 612077 5}
# هلقلقلقلقلق -> term17513 Nt=2 TF=2 maxTF=1 @{0 612083 5}
# هلك -> term24326 Nt=1 TF=1 maxTF=1 @{0 612089 5}
# هلكت -> term23179 Nt=1 TF=1 maxTF=1 @{0 612093 5}
# هلم -> term21583 Nt=1 TF=1 maxTF=1 @{0 612097 5}
# هلمجر -> term24911 Nt=1 TF=1 maxTF=1 @{0 612101 5}
# هله -> term23477 Nt=1 TF=1 maxTF=1 @{0 612105 5}
# هلو -> term9334 Nt=1 TF=1 maxTF=1 @{0 612109 5}
# هلوس -> term19553 Nt=1 TF=1 maxTF=1 @{0 612113 1}
# هليت -> term20985 Nt=1 TF=1 maxTF=1 @{0 612116 7}
# هليكوبتر -> term12718 Nt=1 TF=1 maxTF=1 @{0 612120 7}
# هم -> term17749 Nt=1 TF=1 maxTF=1 @{0 612124 5}
# هماالاخو -> term11245 Nt=1 TF=1 maxTF=1 @{0 612128 3}
# همال -> term23401 Nt=1 TF=1 maxTF=1 @{0 612131 7}
# همام -> term13123 Nt=4 TF=4 maxTF=1 @{0 612135 7}
# همبورج -> term15453 Nt=1 TF=1 maxTF=1 @{0 612146 5}
# همت -> term11415 Nt=1 TF=1 maxTF=1 @{0 612150 3}
# همج -> term7021 Nt=8 TF=8 maxTF=1 @{0 612153 7}
# همجي -> term10718 Nt=1 TF=1 maxTF=1 @{0 612176 7}
# همجيه -> term13583 Nt=3 TF=3 maxTF=1 @{0 612180 3}
# همر -> term20017 Nt=12 TF=12 maxTF=1 @{0 612190 7}
# همرزم -> term22017 Nt=1 TF=1 maxTF=1 @{0 612210 1}
# همرين -> term3615 Nt=1 TF=1 maxTF=1 @{0 612214 1}
# همزه -> term19401 Nt=1 TF=1 maxTF=1 @{0 612216 7}
# همس -> term16487 Nt=1 TF=1 maxTF=1 @{0 612220 5}
# همش -> term12332 Nt=10 TF=16 maxTF=4 @{0 612224 3}
# همكم -> term17750 Nt=1 TF=1 maxTF=1 @{0 612252 7}
# همه -> term15928 Nt=3 TF=3 maxTF=1 @{0 612256 5}
# همو -> term21927 Nt=1 TF=1 maxTF=1 @{0 612266 3}
# هموم -> term14131 Nt=2 TF=2 maxTF=1 @{0 612270 3}
# همين -> term22893 Nt=1 TF=1 maxTF=1 @{0 612276 7}
# هميهف -> term9251 Nt=1 TF=1 maxTF=1 @{0 612280 7}
# هن -> term7425 Nt=2 TF=2 maxTF=1 @{0 612284 3}
# هنا -> term9735 Nt=4 TF=4 maxTF=1 @{0 612291 1}
# هناء -> term623 Nt=1 TF=1 maxTF=1 @{0 612302 5}
# هناحضرمو -> term6172 Nt=1 TF=1 maxTF=1 @{0 612304 5}
# هناكل -> term22627 Nt=1 TF=1 maxTF=1 @{0 612307 7}
# هنام -> term21104 Nt=1 TF=1 maxTF=1 @{0 612311 7}
# هنت -> term21301 Nt=1 TF=1 maxTF=1 @{0 612315 7}
# هنحتاج -> term15329 Nt=1 TF=1 maxTF=1 @{0 612319 7}
# هنخاف -> term24823 Nt=1 TF=1 maxTF=1 @{0 612323 5}
# هنخلص -> term23672 Nt=1 TF=1 maxTF=1 @{0 612327 5}
# هند -> term3556 Nt=41 TF=51 maxTF=2 @{0 612331 5}
# هندريكس -> term6676 Nt=1 TF=1 maxTF=1 @{0 612404 1}
# هندس -> term239 Nt=1 TF=1 maxTF=1 @{0 612407 3}
# هندسه -> term22693 Nt=11 TF=11 maxTF=1 @{0 612408 7}
# هندوس -> term15393 Nt=1 TF=1 maxTF=1 @{0 612421 5}
# هنديه -> term3812 Nt=1 TF=1 maxTF=1 @{0 612425 3}
# هنر -> term7235 Nt=4 TF=4 maxTF=1 @{0 612428 3}
# هنرجع -> term22626 Nt=1 TF=1 maxTF=1 @{0 612441 3}
# هنرسم -> term16247 Nt=1 TF=2 maxTF=2 @{0 612445 3}
# هنسيب -> term24886 Nt=2 TF=2 maxTF=1 @{0 612449 2}
# هنشوف -> term14706 Nt=1 TF=1 maxTF=1 @{0 612455 6}
# هنصح -> term21105 Nt=1 TF=1 maxTF=1 @{0 612459 4}
# هنضم -> term8025 Nt=1 TF=1 maxTF=1 @{0 612463 4}
# هنقدر -> term24411 Nt=1 TF=1 maxTF=1 @{0 612466 6}
# هنكسب -> term19744 Nt=1 TF=1 maxTF=1 @{0 612470 6}
# هنكمل -> term23348 Nt=1 TF=1 maxTF=1 @{0 612474 6}
# هنود -> term16418 Nt=1 TF=1 maxTF=1 @{0 612478 6}
# هنيء -> term13440 Nt=4 TF=4 maxTF=1 @{0 612482 4}
# هه -> term3876 Nt=4 TF=4 maxTF=1 @{0 612494 4}
# ههاج -> term18445 Nt=1 TF=1 maxTF=1 @{0 612507 4}
# ههخع -> term23949 Nt=1 TF=1 maxTF=1 @{0 612511 2}
# ههه -> term302 Nt=283 TF=296 maxTF=3 @{0 612515 2}
# ههها -> term17781 Nt=1 TF=1 maxTF=1 @{0 612998 5}
# هههع -> term24564 Nt=1 TF=1 maxTF=1 @{0 613002 3}
# هو -> term11820 Nt=20 TF=20 maxTF=1 @{0 613006 3}
# هوا -> term9806 Nt=19 TF=19 maxTF=1 @{0 613045 1}
# هواء -> term16013 Nt=9 TF=9 maxTF=1 @{0 613095 3}
# هواءيه -> term18987 Nt=2 TF=2 maxTF=1 @{0 613119 3}
# هواتف -> term3614 Nt=3 TF=3 maxTF=1 @{0 613126 3}
# هوار -> term2928 Nt=1 TF=1 maxTF=1 @{0 613136 5}
# هواش -> term2871 Nt=1 TF=1 maxTF=1 @{0 613139 3}
# هوالمبلغ -> term20077 Nt=1 TF=1 maxTF=1 @{0 613142 1}
# هوب -> term21039 Nt=1 TF=1 maxTF=1 @{0 613146 1}
# هوت -> term4382 Nt=3 TF=3 maxTF=1 @{0 613150 1}
# هوتار -> term19016 Nt=1 TF=1 maxTF=1 @{0 613159 5}
# هوتخل -> term15489 Nt=1 TF=1 maxTF=1 @{0 613163 3}
# هوتش -> term24927 Nt=1 TF=1 maxTF=1 @{0 613167 1}
# هوتيل -> term21890 Nt=5 TF=5 maxTF=1 @{0 613171 1}
# هوجاس -> term16192 Nt=1 TF=1 maxTF=1 @{0 613182 5}
# هوجم -> term12793 Nt=2 TF=2 maxTF=1 @{0 613186 3}
# هوخ -> term21760 Nt=1 TF=1 maxTF=1 @{0 613190 3}
# هوساو -> term17787 Nt=3 TF=3 maxTF=1 @{0 613194 3}
# هوشه -> term13391 Nt=2 TF=2 maxTF=1 @{0 613200 1}
# هوشيار -> term22056 Nt=1 TF=1 maxTF=1 @{0 613206 3}
# هوك -> term24322 Nt=1 TF=1 maxTF=1 @{0 613210 3}
# هول -> term10281 Nt=3 TF=3 maxTF=1 @{0 613214 3}
# هولاء -> term3882 Nt=5 TF=5 maxTF=1 @{0 613224 7}
# هولاك -> term23622 Nt=1 TF=1 maxTF=1 @{0 613241 1}
# هولاند -> term10387 Nt=51 TF=56 maxTF=2 @{0 613245 1}
# هولد -> term20903 Nt=1 TF=1 maxTF=1 @{0 613318 6}
# هولغسيل -> term23877 Nt=1 TF=1 maxTF=1 @{0 613322 6}
# هولند -> term3595 Nt=9 TF=9 maxTF=1 @{0 613326 6}
# هوليباس -> term22268 Nt=1 TF=1 maxTF=1 @{0 613353 4}
# هوليدا -> term20829 Nt=1 TF=1 maxTF=1 @{0 613357 4}
# هولير -> term21695 Nt=7 TF=8 maxTF=2 @{0 613361 4}
# هوليوود -> term23341 Nt=1 TF=1 maxTF=1 @{0 613376 7}
# هوم -> term13240 Nt=1 TF=1 maxTF=1 @{0 613380 7}
# هون -> term12021 Nt=5 TF=5 maxTF=1 @{0 613384 5}
# هونج -> term22039 Nt=2 TF=2 maxTF=1 @{0 613399 3}
# هوند -> term18372 Nt=4 TF=4 maxTF=1 @{0 613406 7}
# هونغ -> term19709 Nt=1 TF=1 maxTF=1 @{0 613417 7}
# هوه -> term19645 Nt=2 TF=2 maxTF=1 @{0 613421 7}
# هوهوهوه -> term5602 Nt=1 TF=1 maxTF=1 @{0 613427 7}
# هووط -> term6212 Nt=1 TF=1 maxTF=1 @{0 613430 7}
# هوي -> term9647 Nt=155 TF=155 maxTF=1 @{0 613434 1}
# هويا -> term5837 Nt=27 TF=27 maxTF=1 @{0 613641 1}
# هويت -> term14097 Nt=3 TF=3 maxTF=1 @{0 613677 7}
# هويشل -> term4132 Nt=2 TF=2 maxTF=1 @{0 613686 1}
# هويه -> term8598 Nt=6 TF=6 maxTF=1 @{0 613692 3}
# هي -> term4806 Nt=21 TF=21 maxTF=1 @{0 613708 7}
# هيء -> term9839 Nt=22 TF=23 maxTF=2 @{0 613762 3}
# هيءا -> term12322 Nt=1 TF=1 maxTF=1 @{0 613816 4}
# هيءه -> term104 Nt=13 TF=13 maxTF=1 @{0 613820 0}
# هياخد -> term17455 Nt=1 TF=1 maxTF=1 @{0 613850 0}
# هياط -> term15224 Nt=1 TF=1 maxTF=1 @{0 613853 6}
# هياكل -> term10642 Nt=3 TF=3 maxTF=1 @{0 613857 4}
# هيام -> term8497 Nt=2 TF=2 maxTF=1 @{0 613867 0}
# هيامعلوم -> term17211 Nt=1 TF=1 maxTF=1 @{0 613873 0}
# هيب -> term4075 Nt=11 TF=11 maxTF=1 @{0 613876 6}
# هيبد -> term11019 Nt=5 TF=5 maxTF=1 @{0 613909 4}
# هيبط -> term7068 Nt=1 TF=1 maxTF=1 @{0 613922 0}
# هيبق -> term14179 Nt=2 TF=2 maxTF=1 @{0 613925 2}
# هيتاش -> term18840 Nt=1 TF=1 maxTF=1 @{0 613932 6}
# هيتاهل -> term18788 Nt=1 TF=1 maxTF=1 @{0 613936 4}
# هيتحر -> term22624 Nt=1 TF=1 maxTF=1 @{0 613940 2}
# هيتعدم -> term20251 Nt=1 TF=1 maxTF=1 @{0 613944 2}
# هيتعمل -> term10678 Nt=2 TF=2 maxTF=1 @{0 613948 2}
# هيتفشخ -> term10722 Nt=1 TF=1 maxTF=1 @{0 613955 4}
# هيتكرر -> term24336 Nt=1 TF=1 maxTF=1 @{0 613959 0}
# هيثم -> term9843 Nt=10 TF=10 maxTF=1 @{0 613963 0}
# هيج -> term18204 Nt=1 TF=1 maxTF=1 @{0 613990 2}
# هيجاءيوما -> term22557 Nt=1 TF=1 maxTF=1 @{0 613994 0}
# هيجمعواملي -> term17468 Nt=1 TF=1 maxTF=1 @{0 613998 0}
# هيجيل -> term8883 Nt=1 TF=1 maxTF=1 @{0 614001 6}
# هيحتاج -> term22103 Nt=1 TF=1 maxTF=1 @{0 614005 2}
# هيحسس -> term13412 Nt=1 TF=1 maxTF=1 @{0 614009 2}
# هيحصل -> term11814 Nt=3 TF=3 maxTF=1 @{0 614013 0}
# هيخسر -> term9226 Nt=1 TF=1 maxTF=1 @{0 614022 2}
# هيخش -> term11289 Nt=1 TF=1 maxTF=1 @{0 614025 6}
# هيخلص -> term13744 Nt=1 TF=1 maxTF=1 @{0 614029 2}
# هيد -> term5565 Nt=8 TF=8 maxTF=1 @{0 614033 0}
# هيدر -> term14524 Nt=1 TF=1 maxTF=1 @{0 614057 4}
# هيدفع -> term10557 Nt=3 TF=3 maxTF=1 @{0 614061 2}
# هيدوس -> term15478 Nt=1 TF=1 maxTF=1 @{0 614071 4}
# هير -> term22489 Nt=2 TF=2 maxTF=1 @{0 614075 2}
# هيرد -> term23470 Nt=1 TF=2 maxTF=2 @{0 614081 6}
# هيرفع -> term11773 Nt=1 TF=1 maxTF=1 @{0 614085 7}
# هيرق -> term24794 Nt=1 TF=1 maxTF=1 @{0 614089 3}
# هيركولانوس -> term12251 Nt=1 TF=1 maxTF=1 @{0 614093 3}
# هيرو -> term1002 Nt=4 TF=4 maxTF=1 @{0 614096 7}
# هيرير -> term15989 Nt=1 TF=1 maxTF=1 @{0 614109 1}
# هيزور -> term10755 Nt=1 TF=1 maxTF=1 @{0 614112 7}
# هيسعر -> term310 Nt=1 TF=1 maxTF=1 @{0 614116 3}
# هيسلم -> term19337 Nt=1 TF=1 maxTF=1 @{0 614117 7}
# هيشدد -> term10515 Nt=1 TF=1 maxTF=1 @{0 614121 5}
# هيشيل -> term10814 Nt=1 TF=1 maxTF=1 @{0 614125 1}
# هيطلع -> term10728 Nt=3 TF=3 maxTF=1 @{0 614128 5}
# هيعلن -> term8283 Nt=1 TF=2 maxTF=2 @{0 614138 3}
# هيعمل -> term19364 Nt=1 TF=1 maxTF=1 @{0 614141 6}
# هيعيد -> term16738 Nt=2 TF=2 maxTF=1 @{0 614145 4}
# هيغ -> term11603 Nt=1 TF=1 maxTF=1 @{0 614152 0}
# هيف -> term4469 Nt=1 TF=1 maxTF=1 @{0 614155 4}
# هيفاء -> term4889 Nt=3 TF=3 maxTF=1 @{0 614158 4}
# هيقشعر -> term20092 Nt=1 TF=1 maxTF=1 @{0 614168 4}
# هيقول -> term14891 Nt=1 TF=1 maxTF=1 @{0 614172 4}
# هيك -> term2035 Nt=18 TF=19 maxTF=2 @{0 614176 2}
# هيكل -> term5763 Nt=41 TF=41 maxTF=1 @{0 614224 1}
# هيكون -> term511 Nt=5 TF=5 maxTF=1 @{0 614289 5}
# هيل -> term12520 Nt=2 TF=2 maxTF=1 @{0 614304 1}
# هيلاق -> term19376 Nt=1 TF=1 maxTF=1 @{0 614311 5}
# هيلبس -> term512 Nt=1 TF=1 maxTF=1 @{0 614315 3}
# هيلت -> term20821 Nt=4 TF=4 maxTF=1 @{0 614317 1}
# هيلو -> term3185 Nt=1 TF=1 maxTF=1 @{0 614329 7}
# هيلوكبتر -> term20062 Nt=1 TF=1 maxTF=1 @{0 614332 5}
# هيلوكوبتر -> term2824 Nt=4 TF=4 maxTF=1 @{0 614336 5}
# هيليغنبل -> term21107 Nt=1 TF=1 maxTF=1 @{0 614341 7}
# هيم -> term4114 Nt=2 TF=2 maxTF=1 @{0 614345 7}
# هيمثل -> term17646 Nt=1 TF=1 maxTF=1 @{0 614352 7}
# هيموت -> term14649 Nt=1 TF=1 maxTF=1 @{0 614356 5}
# هين -> term13958 Nt=4 TF=4 maxTF=1 @{0 614360 3}
# هينا -> term792 Nt=1 TF=1 maxTF=1 @{0 614371 7}
# هينر -> term16907 Nt=1 TF=1 maxTF=1 @{0 614373 7}
# هينطق -> term11861 Nt=2 TF=2 maxTF=1 @{0 614377 5}
# هينين -> term20070 Nt=1 TF=1 maxTF=1 @{0 614383 1}
# هيه -> term11601 Nt=5 TF=5 maxTF=1 @{0 614387 1}
# ...
# يمني -> term7988 Nt=4 TF=4 maxTF=1 @{0 677240 7}
# يمنيه -> term1052 Nt=1233 TF=1335 maxTF=3 @{0 677253 7}
# يمنيهالعربيه -> term7844 Nt=1 TF=1 maxTF=1 @{0 678130 7}
# يمهد -> term3761 Nt=1 TF=1 maxTF=1 @{0 678134 1}
# يمهل -> term10963 Nt=12 TF=12 maxTF=1 @{0 678136 7}
# يمو -> term8020 Nt=13 TF=13 maxTF=1 @{0 678166 1}
# يموت -> term10992 Nt=9 TF=9 maxTF=1 @{0 678200 5}
# يمول -> term24205 Nt=1 TF=1 maxTF=1 @{0 678220 3}
# يمي -> term18577 Nt=1 TF=1 maxTF=1 @{0 678224 3}
# يميل -> term12555 Nt=4 TF=4 maxTF=1 @{0 678228 1}
# يمين -> term2558 Nt=4 TF=4 maxTF=1 @{0 678240 7}
# يمينه -> term19950 Nt=1 TF=1 maxTF=1 @{0 678249 1}
# يمينيه -> term7409 Nt=1 TF=1 maxTF=1 @{0 678253 1}
# ين -> term4847 Nt=13 TF=13 maxTF=1 @{0 678256 3}
# ينا -> term3250 Nt=7 TF=7 maxTF=1 @{0 678280 3}
# يناء -> term3239 Nt=597 TF=668 maxTF=3 @{0 678299 5}
# يناء9الامارا -> term24279 Nt=1 TF=1 maxTF=1 @{0 678766 2}
# يناتور -> term13891 Nt=1 TF=1 maxTF=1 @{0 678770 2}
# ينار -> term11272 Nt=8 TF=8 maxTF=1 @{0 678774 0}
# يناريوها -> term16739 Nt=9 TF=9 maxTF=1 @{0 678794 4}
# يناسب -> term20357 Nt=1 TF=1 maxTF=1 @{0 678811 0}
# يناشد -> term14899 Nt=1 TF=1 maxTF=1 @{0 678815 0}
# يناظر -> term21346 Nt=1 TF=1 maxTF=1 @{0 678818 6}
# يناف -> term20933 Nt=1 TF=1 maxTF=1 @{0 678822 6}
# ينافس -> term11192 Nt=3 TF=3 maxTF=1 @{0 678826 6}
# يناقز -> term12979 Nt=1 TF=1 maxTF=1 @{0 678834 0}
# يناقش -> term13830 Nt=2 TF=2 maxTF=1 @{0 678837 6}
# يناقض -> term15376 Nt=1 TF=1 maxTF=1 @{0 678845 2}
# ينال -> term1983 Nt=9 TF=9 maxTF=1 @{0 678849 0}
# ينالحرس -> term19341 Nt=1 TF=1 maxTF=1 @{0 678870 6}
# ينام -> term6684 Nt=5 TF=5 maxTF=1 @{0 678874 4}
# يناهز -> term17857 Nt=1 TF=1 maxTF=1 @{0 678890 2}
# يناوا -> term21568 Nt=1 TF=1 maxTF=1 @{0 678894 0}
# يناير -> term1687 Nt=180 TF=183 maxTF=2 @{0 678898 0}
# يناير2 -> term18603 Nt=1 TF=1 maxTF=1 @{0 679177 1}
# ينايرال -> term18549 Nt=1 TF=1 maxTF=1 @{0 679180 7}
# ينايرالي12فبراير -> term21522 Nt=1 TF=1 maxTF=1 @{0 679184 5}
# ينبح -> term13292 Nt=3 TF=3 maxTF=1 @{0 679188 5}
# ينبع -> term13792 Nt=1 TF=1 maxTF=1 @{0 679199 3}
# ينبغ -> term5936 Nt=5 TF=5 maxTF=1 @{0 679203 1}
# ينبوع -> term20022 Nt=1 TF=1 maxTF=1 @{0 679219 1}
# ينتبه -> term14061 Nt=2 TF=2 maxTF=1 @{0 679223 1}
# ينتج -> term10215 Nt=10 TF=10 maxTF=1 @{0 679230 5}
# ينتحر -> term17124 Nt=1 TF=1 maxTF=1 @{0 679247 1}
# ينتخب -> term4237 Nt=2 TF=2 maxTF=1 @{0 679250 7}
# ينتر -> term22378 Nt=1 TF=1 maxTF=1 @{0 679257 1}
# ينتشر -> term9607 Nt=18 TF=18 maxTF=1 @{0 679261 1}
# ينتشل -> term16356 Nt=14 TF=14 maxTF=1 @{0 679288 5}
# ينتصر -> term6574 Nt=10 TF=10 maxTF=1 @{0 679299 7}
# ينتظر -> term9028 Nt=8 TF=8 maxTF=1 @{0 679327 3}
# ينتفض -> term15726 Nt=7 TF=7 maxTF=1 @{0 679352 3}
# ينتقد -> term1865 Nt=11 TF=11 maxTF=1 @{0 679370 3}
# ينتقص -> term24213 Nt=1 TF=1 maxTF=1 @{0 679400 7}
# ينتقل -> term10006 Nt=7 TF=7 maxTF=1 @{0 679404 7}
# ينتقم -> term11419 Nt=8 TF=8 maxTF=1 @{0 679418 7}
# ينتل -> term23354 Nt=1 TF=1 maxTF=1 @{0 679442 7}
# ينتم -> term6813 Nt=12 TF=12 maxTF=1 @{0 679446 7}
# ينتمي -> term13469 Nt=1 TF=1 maxTF=1 @{0 679477 5}
# ينته -> term4765 Nt=25 TF=25 maxTF=1 @{0 679481 3}
# ينجاد -> term18140 Nt=1 TF=1 maxTF=1 @{0 679538 7}
# ينجح -> term11460 Nt=17 TF=17 maxTF=1 @{0 679542 5}
# ينجر -> term17033 Nt=2 TF=2 maxTF=1 @{0 679580 1}
# ينجل -> term15571 Nt=1 TF=1 maxTF=1 @{0 679587 5}
# ينجلط -> term14265 Nt=1 TF=1 maxTF=1 @{0 679591 3}
# ينجم -> term10523 Nt=1 TF=1 maxTF=1 @{0 679595 1}
# ينجو -> term7833 Nt=3 TF=3 maxTF=1 @{0 679598 5}
# ينح -> term3975 Nt=2 TF=2 maxTF=1 @{0 679607 1}
# ينحاز -> term18541 Nt=1 TF=1 maxTF=1 @{0 679613 7}
# ينحر -> term15029 Nt=2 TF=2 maxTF=1 @{0 679617 5}
# ينحسد -> term11097 Nt=1 TF=1 maxTF=1 @{0 679624 7}
# ينحك -> term24420 Nt=1 TF=1 maxTF=1 @{0 679628 3}
# ينحل -> term20328 Nt=2 TF=2 maxTF=1 @{0 679632 3}
# ينحن -> term12647 Nt=1 TF=1 maxTF=1 @{0 679637 3}
# ينخ -> term19712 Nt=1 TF=1 maxTF=1 @{0 679641 1}
# يندحر -> term8993 Nt=2 TF=2 maxTF=1 @{0 679645 1}
# يندد -> term9902 Nt=9 TF=9 maxTF=1 @{0 679652 3}
# يندرج -> term15061 Nt=3 TF=3 maxTF=1 @{0 679675 1}
# يندعس -> term19158 Nt=1 TF=1 maxTF=1 @{0 679682 5}
# يندم -> term7867 Nt=2 TF=2 maxTF=1 @{0 679686 3}
# ينزع -> term14350 Nt=1 TF=1 maxTF=1 @{0 679693 3}
# ينزف -> term977 Nt=2 TF=2 maxTF=1 @{0 679697 1}
# ينزل -> term3276 Nt=12 TF=12 maxTF=1 @{0 679703 1}
# ينس -> term10263 Nt=31 TF=32 maxTF=2 @{0 679737 3}
# ينسحب -> term9169 Nt=8 TF=8 maxTF=1 @{0 679801 6}
# ينسر -> term9593 Nt=1 TF=1 maxTF=1 @{0 679827 0}
# ينسف -> term12257 Nt=2 TF=2 maxTF=1 @{0 679830 4}
# ينسو -> term14988 Nt=1 TF=1 maxTF=1 @{0 679835 4}
# ينش -> term17090 Nt=2 TF=2 maxTF=1 @{0 679839 2}
# ينشر -> term2809 Nt=67 TF=68 maxTF=2 @{0 679846 6}
# ينشروم -> term17060 Nt=1 TF=1 maxTF=1 @{0 679971 3}
# ينشط -> term6143 Nt=1 TF=1 maxTF=1 @{0 679975 1}
# ينشق -> term5346 Nt=3 TF=3 maxTF=1 @{0 679978 3}
# ينشيء -> term4704 Nt=1 TF=1 maxTF=1 @{0 679987 7}
# ينصاد -> term23097 Nt=1 TF=1 maxTF=1 @{0 679990 7}
# ينصاع -> term13774 Nt=1 TF=1 maxTF=1 @{0 679994 7}
# ينصب -> term6821 Nt=1 TF=1 maxTF=1 @{0 679998 5}
# ينصدم -> term23741 Nt=1 TF=1 maxTF=1 @{0 680001 7}
# ينصر -> term3866 Nt=12 TF=12 maxTF=1 @{0 680005 7}
# ينصرك -> term21858 Nt=1 TF=1 maxTF=1 @{0 680037 5}
# ينضرب -> term24798 Nt=1 TF=1 maxTF=1 @{0 680041 5}
# ينضف -> term24839 Nt=1 TF=1 maxTF=1 @{0 680045 5}
# ينضمم -> term20636 Nt=15 TF=22 maxTF=2 @{0 680049 5}
# ينطبق -> term23663 Nt=1 TF=1 maxTF=1 @{0 680066 4}
# ينطف -> term18221 Nt=1 TF=1 maxTF=1 @{0 680070 4}
# ينطق -> term14028 Nt=1 TF=1 maxTF=1 @{0 680074 2}
# ينطلق -> term12543 Nt=12 TF=12 maxTF=1 @{0 680078 0}
# ينظر -> term19525 Nt=4 TF=4 maxTF=1 @{0 680104 2}
# ينظم -> term2667 Nt=6 TF=6 maxTF=1 @{0 680116 6}
# ينع -> term3366 Nt=21 TF=21 maxTF=1 @{0 680132 2}
# ينعث -> term8047 Nt=1 TF=1 maxTF=1 @{0 680164 4}
# ينعش -> term15624 Nt=1 TF=1 maxTF=1 @{0 680167 6}
# ينعق -> term7510 Nt=1 TF=1 maxTF=1 @{0 680171 4}
# ينعقد -> term20373 Nt=2 TF=2 maxTF=1 @{0 680174 6}
# ينعكس -> term10746 Nt=2 TF=2 maxTF=1 @{0 680181 0}
# ينعم -> term2066 Nt=1 TF=1 maxTF=1 @{0 680186 6}
# ينعون -> term22808 Nt=1 TF=1 maxTF=1 @{0 680189 2}
# ينغر -> term12700 Nt=5 TF=5 maxTF=1 @{0 680193 2}
# ينغم -> term14738 Nt=1 TF=1 maxTF=1 @{0 680207 0}
# ينغمس -> term22570 Nt=1 TF=2 maxTF=2 @{0 680210 6}
# ينف -> term5968 Nt=37 TF=37 maxTF=1 @{0 680214 7}
# ينفجر -> term1968 Nt=5 TF=5 maxTF=1 @{0 680293 1}
# ينفخ -> term18144 Nt=1 TF=1 maxTF=1 @{0 680309 3}
# ينفذ -> term3823 Nt=37 TF=37 maxTF=1 @{0 680313 1}
# ينفذعمل -> term23131 Nt=1 TF=1 maxTF=1 @{0 680377 7}
# ينفرد -> term23215 Nt=1 TF=1 maxTF=1 @{0 680381 7}
# ينفصل -> term20413 Nt=1 TF=1 maxTF=1 @{0 680385 7}
# ينفع -> term14430 Nt=6 TF=6 maxTF=1 @{0 680389 7}
# ينفون -> term11592 Nt=14 TF=14 maxTF=1 @{0 680406 5}
# ينقاد -> term18543 Nt=2 TF=2 maxTF=1 @{0 680439 1}
# ينقتل -> term13568 Nt=1 TF=1 maxTF=1 @{0 680444 5}
# ينقذ -> term12495 Nt=17 TF=17 maxTF=1 @{0 680448 3}
# ينقص -> term9323 Nt=8 TF=8 maxTF=1 @{0 680486 3}
# ينقطع -> term19773 Nt=1 TF=1 maxTF=1 @{0 680509 5}
# ينقل -> term4257 Nt=10 TF=10 maxTF=1 @{0 680513 5}
# ينقلب -> term19256 Nt=2 TF=2 maxTF=1 @{0 680541 3}
# ينكر -> term15540 Nt=47 TF=47 maxTF=1 @{0 680548 3}
# ينكشف -> term16550 Nt=1 TF=1 maxTF=1 @{0 680572 7}
# ينماء -> term21029 Nt=1 TF=1 maxTF=1 @{0 680576 5}
# يننشال -> term13948 Nt=2 TF=2 maxTF=1 @{0 680580 5}
# ينه -> term4637 Nt=5 TF=5 maxTF=1 @{0 680585 5}
# ينهار -> term9964 Nt=2 TF=2 maxTF=1 @{0 680602 3}
# ينهارر -> term14305 Nt=1 TF=1 maxTF=1 @{0 680609 5}
# ينهب -> term6851 Nt=16 TF=16 maxTF=1 @{0 680613 3}
# ينهبل -> term17580 Nt=1 TF=1 maxTF=1 @{0 680639 5}
# ينهزم -> term14440 Nt=1 TF=1 maxTF=1 @{0 680643 3}
# ينهش -> term7831 Nt=3 TF=3 maxTF=1 @{0 680647 1}
# ينهماعلاقا -> term13961 Nt=1 TF=1 maxTF=1 @{0 680657 3}
# ينهون -> term2085 Nt=4 TF=4 maxTF=1 @{0 680661 1}
# ينو -> term1435 Nt=16 TF=17 maxTF=2 @{0 680669 7}
# ينوب -> term14046 Nt=2 TF=2 maxTF=1 @{0 680689 4}
# ينون -> term22659 Nt=1 TF=1 maxTF=1 @{0 680697 0}
# ينوون -> term19944 Nt=5 TF=5 maxTF=1 @{0 680701 0}
# يني -> term2639 Nt=1 TF=2 maxTF=2 @{0 680711 4}
# ينيام -> term3344 Nt=1 TF=1 maxTF=1 @{0 680714 3}
# ينيق -> term8222 Nt=1 TF=1 maxTF=1 @{0 680717 1}
# ينيك -> term15093 Nt=1 TF=1 maxTF=1 @{0 680720 3}
# يه -> term6732 Nt=6 TF=6 maxTF=1 @{0 680724 1}
# يها -> term8921 Nt=4 TF=4 maxTF=1 @{0 680743 1}
# يهاا -> term24576 Nt=1 TF=1 maxTF=1 @{0 680755 3}
# يهاتش -> term21073 Nt=1 TF=1 maxTF=1 @{0 680759 3}
# يهاجم -> term7384 Nt=51 TF=55 maxTF=2 @{0 680763 3}
# يهان -> term13496 Nt=1 TF=1 maxTF=1 @{0 680856 7}
# يهايط -> term4434 Nt=3 TF=3 maxTF=1 @{0 680860 5}
# يهبط -> term8825 Nt=5 TF=5 maxTF=1 @{0 680870 1}
# يهتز -> term15001 Nt=1 TF=1 maxTF=1 @{0 680879 5}
# يهتف -> term10591 Nt=4 TF=4 maxTF=1 @{0 680883 3}
# يهتم -> term10548 Nt=5 TF=6 maxTF=2 @{0 680895 5}
# يهجم -> term20055 Nt=1 TF=1 maxTF=1 @{0 680911 0}
# يهد -> term6303 Nt=6 TF=6 maxTF=1 @{0 680915 0}
# يهدد -> term1789 Nt=47 TF=47 maxTF=1 @{0 680934 2}
# يهددمفاوضا -> term4043 Nt=1 TF=1 maxTF=1 @{0 681033 2}
# يهدف -> term16644 Nt=6 TF=6 maxTF=1 @{0 681036 2}
# يهدون -> term11924 Nt=1 TF=1 maxTF=1 @{0 681051 4}
# يهديج -> term17108 Nt=1 TF=1 maxTF=1 @{0 681055 0}
# يهرب -> term5747 Nt=8 TF=8 maxTF=1 @{0 681058 6}
# يهز -> term7241 Nt=29 TF=30 maxTF=2 @{0 681083 4}
# يهزء -> term12795 Nt=1 TF=1 maxTF=1 @{0 681137 3}
# يهزان -> term14998 Nt=19 TF=19 maxTF=1 @{0 681141 1}
# يهزج -> term9774 Nt=1 TF=1 maxTF=1 @{0 681165 1}
# يهزم -> term7485 Nt=43 TF=44 maxTF=2 @{0 681168 5}
# يهزمد -> term7366 Nt=1 TF=1 maxTF=1 @{0 681219 2}
# يهقب -> term24898 Nt=1 TF=1 maxTF=1 @{0 681222 4}
# يهكر -> term4432 Nt=1 TF=2 maxTF=2 @{0 681226 4}
# يهل -> term3867 Nt=2 TF=2 maxTF=1 @{0 681229 5}
# يهم -> term7444 Nt=22 TF=22 maxTF=1 @{0 681236 3}
# يهمش -> term9676 Nt=1 TF=1 maxTF=1 @{0 681294 7}
# يهمل -> term10966 Nt=3 TF=3 maxTF=1 @{0 681298 3}
# يهن -> term16708 Nt=2 TF=2 maxTF=1 @{0 681309 1}
# يهنء -> term21787 Nt=10 TF=10 maxTF=1 @{0 681315 7}
# يهنيء -> term17670 Nt=12 TF=12 maxTF=1 @{0 681340 1}
# يهو -> term1723 Nt=2 TF=2 maxTF=1 @{0 681362 5}
# يهود -> term2739 Nt=84 TF=88 maxTF=3 @{0 681369 1}
# يهودي -> term14112 Nt=1 TF=1 maxTF=1 @{0 681520 7}
# يهوديه -> term11960 Nt=33 TF=33 maxTF=1 @{0 681524 5}
# يهيض -> term24913 Nt=1 TF=1 maxTF=1 @{0 681570 3}
# يهيكل -> term24089 Nt=2 TF=2 maxTF=1 @{0 681574 3}
# يهيم -> term10748 Nt=1 TF=1 maxTF=1 @{0 681580 7}
# يهين -> term8610 Nt=4 TF=4 maxTF=1 @{0 681584 3}
# يو -> term1001 Nt=27 TF=27 maxTF=1 @{0 681598 3}
# يواج -> term12356 Nt=27 TF=27 maxTF=1 @{0 681638 1}
# يواجه -> term5714 Nt=6 TF=6 maxTF=1 @{0 681684 7}
# يواجهشمش -> term21079 Nt=2 TF=2 maxTF=1 @{0 681703 3}
# يواخيم -> term16961 Nt=1 TF=1 maxTF=1 @{0 681708 5}
# يواصل -> term12238 Nt=23 TF=23 maxTF=1 @{0 681712 3}
# يوافق -> term4557 Nt=35 TF=35 maxTF=1 @{0 681751 7}
# يوال -> term23585 Nt=1 TF=1 maxTF=1 @{0 681806 5}
# يوب -> term15954 Nt=2 TF=2 maxTF=1 @{0 681810 5}
# يوت -> term17092 Nt=1 TF=1 maxTF=1 @{0 681814 5}
# يوتوب -> term16839 Nt=2 TF=2 maxTF=1 @{0 681818 3}
# يوتيوب -> term4012 Nt=236 TF=239 maxTF=2 @{0 681823 7}
# يوثق -> term20190 Nt=1 TF=1 maxTF=1 @{0 682049 6}
# يوج -> term1418 Nt=32 TF=34 maxTF=2 @{0 682053 6}
# يوجد -> term4709 Nt=59 TF=60 maxTF=2 @{0 682113 6}
# يوجع -> term22397 Nt=1 TF=1 maxTF=1 @{0 682240 3}
# يوجه -> term10406 Nt=4 TF=4 maxTF=1 @{0 682244 3}
# يوجود -> term17786 Nt=1 TF=1 maxTF=1 @{0 682255 3}
# يوح -> term2510 Nt=8 TF=10 maxTF=2 @{0 682259 1}
# يوحا -> term23373 Nt=3 TF=3 maxTF=1 @{0 682280 1}
# يوحد -> term3766 Nt=1 TF=1 maxTF=1 @{0 682287 7}
# يوحنا9 -> term17925 Nt=1 TF=1 maxTF=1 @{0 682290 5}
# يوخا -> term23538 Nt=1 TF=1 maxTF=1 @{0 682294 3}
# يود -> term981 Nt=11 TF=12 maxTF=2 @{0 682298 3}
# يودع -> term12976 Nt=3 TF=3 maxTF=1 @{0 682328 2}
# يودي -> term15037 Nt=1 TF=1 maxTF=1 @{0 682337 2}
# يور -> term5474 Nt=5 TF=5 maxTF=1 @{0 682341 0}
# يوربا -> term17702 Nt=1 TF=1 maxTF=1 @{0 682347 4}
# يورباليغ -> term4629 Nt=3 TF=3 maxTF=1 @{0 682351 2}
# يورتيش -> term12912 Nt=1 TF=1 maxTF=1 @{0 682357 0}
# يورد -> term9236 Nt=3 TF=3 maxTF=1 @{0 682360 6}
# يورو -> term69 Nt=305 TF=372 maxTF=3 @{0 682366 6}
# يورورنيوز -> term9986 Nt=2 TF=2 maxTF=1 @{0 682675 3}
# يورونيوز -> term3099 Nt=2 TF=2 maxTF=1 @{0 682680 1}
# يوريتش -> term12921 Nt=1 TF=1 maxTF=1 @{0 682686 3}
# يوريش -> term12950 Nt=1 TF=1 maxTF=1 @{0 682690 1}
# يوز -> term18750 Nt=1 TF=1 maxTF=1 @{0 682693 7}
# يوزع -> term5781 Nt=7 TF=7 maxTF=1 @{0 682697 5}
# يوس -> term17105 Nt=1 TF=1 maxTF=1 @{0 682718 1}
# يوستريم -> term15464 Nt=6 TF=6 maxTF=1 @{0 682721 7}
# يوسع -> term18872 Nt=2 TF=2 maxTF=1 @{0 682731 5}
# يوسف -> term3774 Nt=37 TF=38 maxTF=2 @{0 682738 7}
# يوسفيه -> term24948 Nt=1 TF=1 maxTF=1 @{0 682815 2}
# يوش -> term24203 Nt=2 TF=2 maxTF=1 @{0 682819 2}
# يوشع -> term23340 Nt=2 TF=2 maxTF=1 @{0 682826 0}
# يوص -> term17541 Nt=1 TF=1 maxTF=1 @{0 682832 4}
# يوصف -> term20315 Nt=11 TF=11 maxTF=1 @{0 682836 2}
# يوصل -> term13051 Nt=5 TF=5 maxTF=1 @{0 682854 2}
# يوضح -> term3014 Nt=6 TF=6 maxTF=1 @{0 682870 2}
# يوظف -> term12945 Nt=1 TF=1 maxTF=1 @{0 682889 4}
# يوعد -> term23119 Nt=1 TF=1 maxTF=1 @{0 682893 2}
# يوف -> term9585 Nt=7 TF=7 maxTF=1 @{0 682897 2}
# يوفر -> term5564 Nt=2 TF=2 maxTF=1 @{0 682918 2}
# يوفق -> term9595 Nt=31 TF=31 maxTF=1 @{0 682924 6}
# يوفنت -> term17946 Nt=1 TF=1 maxTF=1 @{0 682997 4}
# يوفنتوس -> term14349 Nt=5 TF=6 maxTF=2 @{0 683001 2}
# يوفون -> term23052 Nt=1 TF=1 maxTF=1 @{0 683016 3}
# يوفيتش -> term14722 Nt=1 TF=1 maxTF=1 @{0 683020 3}
# يوقظ -> term17153 Nt=2 TF=2 maxTF=1 @{0 683024 1}
# يوقع -> term903 Nt=162 TF=163 maxTF=2 @{0 683030 1}
# يوقف -> term5751 Nt=4 TF=4 maxTF=1 @{0 683182 2}
# يوكو -> term14651 Nt=1 TF=1 maxTF=1 @{0 683196 0}
# يوكيك -> term23604 Nt=1 TF=1 maxTF=1 @{0 683199 6}
# يول -> term1895 Nt=6 TF=6 maxTF=1 @{0 683203 6}
# يولاندس -> term10834 Nt=5 TF=5 maxTF=1 @{0 683216 0}
# يولد -> term11234 Nt=3 TF=3 maxTF=1 @{0 683230 6}
# يولع -> term11571 Nt=2 TF=2 maxTF=1 @{0 683240 4}
# يوم -> term160 Nt=2392 TF=2475 maxTF=6 @{0 683247 4}
# يوم17 -> term18556 Nt=1 TF=1 maxTF=1 @{0 685631 5}
# يوم8275وال -> term17444 Nt=1 TF=1 maxTF=1 @{0 685635 3}
# يوما -> term19757 Nt=1 TF=1 maxTF=1 @{0 685639 1}
# يوماف -> term24697 Nt=1 TF=1 maxTF=1 @{0 685643 1}
# يومافاد -> term7319 Nt=1 TF=1 maxTF=1 @{0 685647 1}
# يومالسبت -> term5167 Nt=1 TF=1 maxTF=1 @{0 685650 3}
# يومي -> term5562 Nt=4 TF=4 maxTF=1 @{0 685653 3}
# يوميا -> term9341 Nt=6 TF=6 maxTF=1 @{0 685666 5}
# يومين -> term8702 Nt=31 TF=31 maxTF=1 @{0 685685 1}
# يوميه -> term2516 Nt=3 TF=3 maxTF=1 @{0 685760 7}
# يون -> term2010 Nt=218 TF=243 maxTF=2 @{0 685770 5}
# يونا -> term2125 Nt=94 TF=96 maxTF=2 @{0 686027 6}
# يونان -> term4595 Nt=49 TF=49 maxTF=1 @{0 686130 0}
# يونانيه -> term4986 Nt=34 TF=34 maxTF=1 @{0 686192 6}
# يونايتد -> term12284 Nt=2 TF=3 maxTF=2 @{0 686242 6}
# يوناينه -> term8671 Nt=1 TF=1 maxTF=1 @{0 686249 7}
# يونج -> term21151 Nt=7 TF=8 maxTF=2 @{0 686253 3}
# يونجيانج -> term822 Nt=2 TF=2 maxTF=1 @{0 686268 4}
# يونس -> term13033 Nt=10 TF=10 maxTF=1 @{0 686273 4}
# يونسكو -> term11390 Nt=2 TF=2 maxTF=1 @{0 686299 4}
# يونغ -> term4712 Nt=44 TF=44 maxTF=1 @{0 686305 0}
# يونغيانغ -> term4723 Nt=16 TF=16 maxTF=1 @{0 686368 6}
# يونق -> term21425 Nt=1 TF=1 maxTF=1 @{0 686389 4}
# يونقج -> term3010 Nt=1 TF=1 maxTF=1 @{0 686393 4}
# يونيفل -> term23253 Nt=2 TF=2 maxTF=1 @{0 686396 2}
# يونيفيل -> term23169 Nt=3 TF=3 maxTF=1 @{0 686403 2}
# يونين -> term2831 Nt=2 TF=2 maxTF=1 @{0 686410 4}
# يوهو -> term16866 Nt=1 TF=1 maxTF=1 @{0 686416 4}
# يوهي -> term2757 Nt=1 TF=1 maxTF=1 @{0 686420 2}
# يووم -> term506 Nt=2 TF=2 maxTF=1 @{0 686423 0}
# يويفا -> term14810 Nt=1 TF=1 maxTF=1 @{0 686428 2}
# يوينغ -> term21297 Nt=1 TF=1 maxTF=1 @{0 686432 0}
# ييب -> term22409 Nt=1 TF=1 maxTF=1 @{0 686436 0}
# ييج -> term24888 Nt=1 TF=1 maxTF=1 @{0 686440 0}
# ييدو -> term3612 Nt=1 TF=1 maxTF=1 @{0 686444 0}
# يير -> term3855 Nt=13 TF=13 maxTF=1 @{0 686446 6}
# ييس -> term23920 Nt=1 TF=1 maxTF=1 @{0 686475 2}
# ييسرل -> term6567 Nt=1 TF=1 maxTF=1 @{0 686479 2}
# ييكتشرز -> term6027 Nt=15 TF=15 maxTF=1 @{0 686482 4}
# يين -> term18210 Nt=1 TF=1 maxTF=1 @{0 686507 4}
# ييير -> term18475 Nt=1 TF=1 maxTF=1 @{0 686511 2}
# ييين -> term9159 Nt=2 TF=2 maxTF=1 @{0 686515 0}
# ৩ -> term24236 Nt=1 TF=1 maxTF=1 @{0 686522 2}

# %% [markdown]
# ### **Exercise1**
# How many documents mention your country name? which documents are those?

# %%
term="الجزائر"
term=normalize(term)
term=ar_stemmer.stemWord(term)
print("The number of documents that mention %s is %s"%(term,index.getLexicon()[term].getDocumentFrequency()))
# Out:
# The number of documents that mention جزاءر is 337

# %%
pointer = index.getLexicon()[term]
for posting in index.getInvertedIndex().getPostings(pointer):
    print(posting.toString() + " doclen=%d" % posting.getDocumentLength())
# Out:
# ID(608) TF(2) doclen=14
# ID(761) TF(1) doclen=12
# ID(1406) TF(1) doclen=9
# ID(2230) TF(1) doclen=11
# ID(3362) TF(1) doclen=12
# ID(4501) TF(1) doclen=19
# ID(5047) TF(1) doclen=7
# ID(5186) TF(1) doclen=13
# ID(5187) TF(1) doclen=13
# ID(5188) TF(1) doclen=13
# ID(5189) TF(1) doclen=13
# ID(5190) TF(1) doclen=13
# ID(5389) TF(1) doclen=13
# ID(5390) TF(1) doclen=13
# ID(5432) TF(1) doclen=13
# ID(5433) TF(1) doclen=13
# ID(5434) TF(1) doclen=13
# ID(5435) TF(1) doclen=13
# ID(5551) TF(1) doclen=13
# ID(5553) TF(1) doclen=13
# ID(5554) TF(1) doclen=13
# ID(5570) TF(1) doclen=17
# ID(5773) TF(1) doclen=18
# ID(6425) TF(1) doclen=15
# ID(6426) TF(1) doclen=15
# ID(6427) TF(1) doclen=15
# ID(6428) TF(1) doclen=15
# ID(6429) TF(1) doclen=15
# ID(6604) TF(1) doclen=16
# ID(6605) TF(1) doclen=16
# ID(6607) TF(1) doclen=16
# ID(6608) TF(1) doclen=16
# ID(6687) TF(1) doclen=15
# ID(6688) TF(1) doclen=15
# ID(8514) TF(1) doclen=15
# ID(8515) TF(1) doclen=15
# ID(8672) TF(1) doclen=15
# ID(8674) TF(1) doclen=15
# ID(8742) TF(1) doclen=15
# ID(8743) TF(1) doclen=15
# ID(8744) TF(1) doclen=15
# ID(9424) TF(1) doclen=10
# ID(10011) TF(1) doclen=8
# ID(10012) TF(1) doclen=9
# ID(10490) TF(1) doclen=9
# ID(10629) TF(1) doclen=6
# ID(12844) TF(1) doclen=3
# ID(12939) TF(1) doclen=5
# ID(12976) TF(1) doclen=7
# ID(13204) TF(1) doclen=5
# ID(13241) TF(1) doclen=21
# ID(13310) TF(1) doclen=14
# ID(13318) TF(1) doclen=14
# ID(13355) TF(1) doclen=10
# ID(13388) TF(1) doclen=15
# ID(13393) TF(1) doclen=19
# ID(13418) TF(1) doclen=13
# ID(13433) TF(1) doclen=15
# ID(13434) TF(2) doclen=14
# ID(13438) TF(1) doclen=20
# ID(13439) TF(1) doclen=19
# ID(13449) TF(1) doclen=19
# ID(13452) TF(1) doclen=5
# ID(13464) TF(1) doclen=15
# ID(13475) TF(1) doclen=4
# ID(13480) TF(1) doclen=16
# ID(13482) TF(1) doclen=14
# ID(13506) TF(1) doclen=12
# ID(13507) TF(1) doclen=7
# ID(13519) TF(2) doclen=21
# ID(13523) TF(1) doclen=14
# ID(13596) TF(1) doclen=7
# ID(13597) TF(1) doclen=16
# ID(13671) TF(1) doclen=15
# ID(13675) TF(1) doclen=9
# ID(13700) TF(1) doclen=16
# ID(13719) TF(1) doclen=3
# ID(13832) TF(1) doclen=12
# ID(13848) TF(2) doclen=7
# ID(13904) TF(1) doclen=19
# ID(13969) TF(1) doclen=15
# ID(13972) TF(1) doclen=15
# ID(14036) TF(1) doclen=19
# ID(14059) TF(1) doclen=14
# ID(14073) TF(1) doclen=3
# ID(14226) TF(1) doclen=18
# ID(14422) TF(1) doclen=14
# ID(14438) TF(1) doclen=10
# ID(14537) TF(1) doclen=18
# ID(14646) TF(1) doclen=12
# ID(14705) TF(1) doclen=12
# ID(14769) TF(1) doclen=17
# ID(14855) TF(1) doclen=20
# ID(14908) TF(1) doclen=6
# ID(15166) TF(1) doclen=17
# ID(15227) TF(1) doclen=7
# ID(15298) TF(1) doclen=14
# ID(15299) TF(1) doclen=14
# ID(15431) TF(1) doclen=15
# ID(15432) TF(1) doclen=15
# ID(15433) TF(1) doclen=15
# ID(15434) TF(1) doclen=15
# ID(15501) TF(1) doclen=13
# ID(15502) TF(1) doclen=13
# ID(15503) TF(1) doclen=13
# ID(15730) TF(1) doclen=14
# ID(15877) TF(1) doclen=13
# ID(15878) TF(1) doclen=13
# ID(16051) TF(1) doclen=9
# ID(16057) TF(1) doclen=17
# ID(16472) TF(1) doclen=4
# ID(17975) TF(1) doclen=5
# ID(18462) TF(1) doclen=7
# ID(19013) TF(1) doclen=10
# ID(19063) TF(1) doclen=5
# ID(19118) TF(1) doclen=12
# ID(19317) TF(1) doclen=13
# ID(19637) TF(1) doclen=12
# ID(19639) TF(1) doclen=19
# ID(19777) TF(1) doclen=9
# ID(19854) TF(1) doclen=14
# ID(19899) TF(2) doclen=11
# ID(20445) TF(1) doclen=11
# ID(20556) TF(2) doclen=14
# ID(20594) TF(1) doclen=17
# ID(20642) TF(1) doclen=10
# ID(20681) TF(1) doclen=17
# ID(20698) TF(2) doclen=13
# ID(20864) TF(1) doclen=6
# ID(21039) TF(2) doclen=18
# ID(21140) TF(1) doclen=5
# ID(21658) TF(1) doclen=4
# ID(21748) TF(1) doclen=4
# ID(21908) TF(1) doclen=9
# ID(22382) TF(1) doclen=7
# ID(23884) TF(1) doclen=3
# ID(24278) TF(1) doclen=6
# ID(24693) TF(1) doclen=5
# ID(24968) TF(1) doclen=15
# ID(24969) TF(1) doclen=15
# ID(25103) TF(1) doclen=17
# ID(25104) TF(1) doclen=17
# ID(25105) TF(1) doclen=17
# ID(25107) TF(1) doclen=17
# ID(25108) TF(1) doclen=17
# ID(25386) TF(1) doclen=15
# ID(26569) TF(1) doclen=9
# ID(26641) TF(2) doclen=14
# ID(27653) TF(1) doclen=12
# ID(28491) TF(1) doclen=13
# ID(28846) TF(1) doclen=11
# ID(29071) TF(1) doclen=12
# ID(29149) TF(2) doclen=17
# ID(29150) TF(2) doclen=17
# ID(29151) TF(2) doclen=17
# ID(29161) TF(2) doclen=17
# ID(29168) TF(2) doclen=17
# ID(29178) TF(1) doclen=15
# ID(29188) TF(2) doclen=17
# ID(29231) TF(2) doclen=17
# ID(29255) TF(1) doclen=7
# ID(29329) TF(1) doclen=14
# ID(29354) TF(1) doclen=14
# ID(29434) TF(2) doclen=16
# ID(29457) TF(1) doclen=13
# ID(29465) TF(1) doclen=15
# ID(29477) TF(1) doclen=18
# ID(29483) TF(2) doclen=12
# ID(29510) TF(1) doclen=19
# ID(29529) TF(1) doclen=14
# ID(29546) TF(1) doclen=6
# ID(29550) TF(1) doclen=5
# ID(29565) TF(1) doclen=15
# ID(29566) TF(1) doclen=15
# ID(29567) TF(1) doclen=8
# ID(29575) TF(1) doclen=16
# ID(29576) TF(1) doclen=7
# ID(29582) TF(1) doclen=14
# ID(29584) TF(1) doclen=16
# ID(29585) TF(1) doclen=14
# ID(29590) TF(1) doclen=15
# ID(29602) TF(1) doclen=19
# ID(29604) TF(1) doclen=9
# ID(29605) TF(1) doclen=15
# ID(29606) TF(2) doclen=13
# ID(29613) TF(1) doclen=11
# ID(29617) TF(1) doclen=10
# ID(29622) TF(1) doclen=11
# ID(29623) TF(1) doclen=11
# ID(29627) TF(1) doclen=11
# ID(29630) TF(1) doclen=9
# ID(29632) TF(1) doclen=8
# ID(29633) TF(1) doclen=13
# ID(29634) TF(1) doclen=9
# ID(29636) TF(1) doclen=18
# ID(29640) TF(1) doclen=8
# ID(29641) TF(1) doclen=8
# ID(29642) TF(1) doclen=17
# ID(29643) TF(1) doclen=15
# ID(29653) TF(1) doclen=16
# ID(29655) TF(1) doclen=16
# ID(29661) TF(1) doclen=16
# ID(29663) TF(1) doclen=6
# ID(29685) TF(1) doclen=10
# ID(29690) TF(1) doclen=7
# ID(29701) TF(1) doclen=14
# ID(29710) TF(1) doclen=12
# ID(29714) TF(1) doclen=10
# ID(29715) TF(1) doclen=10
# ID(29716) TF(1) doclen=16
# ID(29722) TF(2) doclen=9
# ID(29723) TF(1) doclen=9
# ID(29726) TF(1) doclen=16
# ID(29727) TF(1) doclen=8
# ID(29733) TF(1) doclen=16
# ID(29758) TF(1) doclen=13
# ID(29782) TF(1) doclen=7
# ID(29791) TF(1) doclen=10
# ID(29793) TF(1) doclen=12
# ID(29999) TF(2) doclen=16
# ID(30052) TF(1) doclen=12
# ID(30150) TF(2) doclen=23
# ID(30209) TF(1) doclen=8
# ID(30216) TF(1) doclen=11
# ID(30589) TF(1) doclen=24
# ID(30863) TF(1) doclen=17
# ID(31000) TF(1) doclen=15
# ID(31001) TF(1) doclen=15
# ID(31039) TF(1) doclen=5
# ID(31086) TF(1) doclen=22
# ID(31267) TF(1) doclen=15
# ID(32220) TF(1) doclen=13
# ID(32289) TF(1) doclen=17
# ID(32314) TF(2) doclen=14
# ID(32360) TF(1) doclen=14
# ID(32367) TF(1) doclen=14
# ID(32392) TF(1) doclen=12
# ID(32398) TF(1) doclen=12
# ID(32399) TF(1) doclen=12
# ID(32402) TF(1) doclen=15
# ID(32404) TF(1) doclen=13
# ID(32408) TF(1) doclen=15
# ID(32413) TF(1) doclen=15
# ID(32416) TF(1) doclen=11
# ID(32422) TF(3) doclen=19
# ID(32495) TF(2) doclen=16
# ID(32496) TF(1) doclen=10
# ID(32502) TF(2) doclen=16
# ID(32504) TF(1) doclen=12
# ID(32505) TF(1) doclen=12
# ID(32508) TF(1) doclen=17
# ID(32510) TF(1) doclen=14
# ID(32514) TF(1) doclen=14
# ID(32532) TF(2) doclen=16
# ID(32533) TF(2) doclen=16
# ID(32539) TF(1) doclen=7
# ID(32547) TF(1) doclen=14
# ID(32554) TF(1) doclen=9
# ID(32555) TF(1) doclen=9
# ID(32556) TF(1) doclen=7
# ID(32557) TF(2) doclen=16
# ID(32584) TF(1) doclen=10
# ID(32711) TF(2) doclen=13
# ID(32816) TF(1) doclen=5
# ID(32821) TF(3) doclen=14
# ID(32937) TF(1) doclen=17
# ID(33843) TF(1) doclen=16
# ID(34458) TF(1) doclen=14
# ID(34459) TF(1) doclen=14
# ID(34460) TF(1) doclen=14
# ID(34597) TF(1) doclen=15
# ID(34598) TF(1) doclen=15
# ID(34600) TF(1) doclen=15
# ID(34602) TF(1) doclen=15
# ID(34604) TF(1) doclen=15
# ID(34795) TF(1) doclen=16
# ID(35367) TF(1) doclen=11
# ID(36623) TF(1) doclen=14
# ID(37488) TF(1) doclen=13
# ID(37489) TF(1) doclen=13
# ID(37490) TF(1) doclen=13
# ID(37491) TF(1) doclen=13
# ID(37492) TF(1) doclen=13
# ID(37493) TF(1) doclen=13
# ID(37494) TF(1) doclen=13
# ID(37731) TF(1) doclen=14
# ID(37732) TF(1) doclen=14
# ID(37733) TF(1) doclen=14
# ID(37735) TF(1) doclen=14
# ID(39760) TF(1) doclen=3
# ID(39766) TF(1) doclen=16
# ID(41232) TF(1) doclen=13
# ID(41315) TF(1) doclen=12
# ID(41316) TF(1) doclen=12
# ID(41488) TF(1) doclen=12
# ID(41489) TF(1) doclen=12
# ID(41621) TF(1) doclen=12
# ID(41623) TF(1) doclen=12
# ID(41624) TF(1) doclen=12
# ID(41675) TF(1) doclen=12
# ID(41676) TF(1) doclen=12
# ID(41677) TF(1) doclen=12
# ID(41895) TF(1) doclen=5
# ID(43555) TF(1) doclen=6
# ID(44025) TF(1) doclen=13
# ID(44026) TF(1) doclen=13
# ID(44027) TF(1) doclen=13
# ID(44028) TF(1) doclen=13
# ID(46011) TF(1) doclen=14
# ID(46012) TF(1) doclen=14
# ID(46189) TF(1) doclen=14
# ID(46190) TF(1) doclen=14
# ID(46191) TF(1) doclen=14
# ID(46192) TF(1) doclen=14
# ID(46193) TF(1) doclen=14
# ID(46194) TF(1) doclen=14
# ID(46214) TF(1) doclen=13
# ID(46215) TF(1) doclen=13
# ID(46216) TF(1) doclen=13
# ID(46516) TF(1) doclen=17
# ID(48145) TF(1) doclen=11
# ID(48146) TF(1) doclen=11
# ID(48634) TF(1) doclen=14
# ID(48636) TF(1) doclen=14
# ID(48637) TF(1) doclen=14
# ID(48688) TF(1) doclen=15
# ID(48689) TF(1) doclen=15
# ID(48690) TF(1) doclen=15
# ID(48691) TF(1) doclen=15
# ID(48692) TF(1) doclen=15
# ID(48694) TF(1) doclen=15
# ID(48851) TF(1) doclen=14
# ID(48852) TF(1) doclen=14
# ID(48853) TF(1) doclen=14
# ID(48854) TF(1) doclen=14
# ID(48855) TF(1) doclen=14
# ID(48856) TF(1) doclen=14

# %% [markdown]
# ### **Exercise2**
# Select any document from the collection and check which of its terms appear in the index?

# %%
#let's say we want to check the 100th document
di = index.getDirectIndex()
doi = index.getDocumentIndex()
lex = index.getLexicon()
docid = 100 #docids are 0-based #note: postings will be null if the document is empty
for posting in di.getPostings(doi.getDocumentEntry(docid)):
    termid = posting.getId()
    lee = lex.getLexiconEntry(termid)
    print("%s with frequency %d" % (lee.getKey(),posting.getFrequency()))
# Out:
# اخبار with frequency 1
# تفجير with frequency 1
# استقبل with frequency 1
# جريح with frequency 1
# نواب with frequency 1
# طبرق with frequency 2
# استهدف with frequency 1
# مجلس with frequency 1
# مقر with frequency 1
# جراء with frequency 1
# مركز with frequency 1
# 19 with frequency 1
# دردنيل with frequency 1
# الطب with frequency 1

# %%
# #temporary to exporte the index to the local machine and keep a copy in our github
# !ls -lh evetarIndex/
# # #download and save the index
#from google.colab import files
# files.download("data.direct.bf")
# !zip -r ./evetarIndex.zip ./evetarIndex
files.download("evetarIndex.zip")
# Out:
# total 6.7M
# -rw-r--r-- 1 root root 1.1M May 25 10:58 data.direct.bf
# -rw-r--r-- 1 root root 831K May 25 10:58 data.document.fsarrayfile
# -rw-r--r-- 1 root root 671K May 25 10:58 data.inverted.bf
# -rw-r--r-- 1 root root 2.1M May 25 10:58 data.lexicon.fsomapfile
# -rw-r--r-- 1 root root 1.1K May 25 10:58 data.lexicon.fsomaphash
# -rw-r--r-- 1 root root  98K May 25 10:58 data.lexicon.fsomapid
# -rw-r--r-- 1 root root 391K May 25 10:58 data.meta.idx
# -rw-r--r-- 1 root root 1.7M May 25 10:58 data.meta.zdata
# -rw-r--r-- 1 root root 4.1K May 25 10:58 data.properties

# %% [markdown]
# ### **References**
#
#
# *   IR From Bag-of-words to BERT and Beyond through Practical Experiments. [PyTerrier ECIR2021 Tutorial](https://github.com/terrier-org/ecir2021tutorial).
# *   [PyTerrier documentation.](https://pyterrier.readthedocs.io/_/downloads/en/latest/pdf/)
